# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds

# %% [markdown]
# ### Most Common Words

# %% [markdown]
# **Analysis**

# %%
##Read Document Term Matrix
import pandas as pd
import numpy as np

books_tdm = pd.read_pickle('books_tdm.pkl')
books_tdm = books_tdm.transpose()

# %%
books_tdm.head()
# Out:
# books      Bahai_Aqdas  Budhist_Tipitaka  Gita  Rigveda  Jewish_bible  Quran  \
# aa                   0                 0     3        3             0      0
# aaa                  0                 0     1        0             0      0
# aaay                 0                 0     0        0             0      0
# aab                  0                 0     0        0             0      0
# aabaadaan            0                 0     0        0             0      0
#
# books      Gurugranthsahib  Bible
# aa                     325      0
# aaa                      0      0
# aaay                   509      0
# aab                      4      0
# aabaadaan                1      0

# %%
# Find the top 30 words from the books
top_dict = {}
for c in books_tdm.columns:
    top = books_tdm[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index,top.values))

top_30_df = pd.DataFrame(top_dict)
top_30_df
# Out:
#           Bahai_Aqdas  Budhist_Tipitaka                   Gita  \
# 0          (god, 613)     (buddha, 709)           (lord, 1928)
# 1         (hath, 421)      (sutta, 485)        (supreme, 1702)
# 2           (ye, 296)  (discourse, 202)       (material, 1437)
# 3       (prayer, 198)     (dhamma, 167)           (book, 1066)
# 4        (house, 189)       (life, 139)  (bhaktivedanta, 1063)
# 5          (law, 189)    (bhikkhu, 136)          (right, 1052)
# 6         (lord, 181)  (venerable, 132)      (copyright, 1031)
# 7      (justice, 171)   (bhikkhus, 129)          (trust, 1030)
# 8          (day, 167)      (given, 124)       (reserved, 1028)
# 9         (unto, 166)       (mind, 105)           (intl, 1026)
# 10    (question, 152)   (practice, 100)   (consciousness, 879)
# 11        (book, 139)    (teaching, 96)          (living, 796)
# 12         (thy, 135)     (offence, 90)            (body, 771)
# 13      (people, 130)        (rule, 88)       (knowledge, 733)
# 14      (answer, 129)       (order, 86)            (life, 721)
# 15       (world, 128)   (knowledge, 84)     (personality, 703)
# 16  (obligatory, 121)       (vagga, 81)          (arjuna, 700)
# 17       (verse, 117)        (view, 81)         (service, 691)
# 18        (time, 117)       (world, 79)          (entity, 686)
# 19      (tablet, 112)    (disciple, 75)         (godhead, 680)
# 20       (shall, 106)      (person, 73)         (purport, 664)
# 21      (verily, 104)        (path, 71)            (text, 663)
# 22    (revealed, 101)        (para, 71)     (translation, 659)
# 23       (shoghi, 99)         (way, 70)         (synonym, 657)
# 24      (effendi, 99)  (meditation, 69)       (spiritual, 652)
# 25         (thee, 98)        (king, 69)        (activity, 649)
# 26         (word, 95)   (explained, 69)          (person, 638)
# 27         (year, 91)       (wrong, 67)            (soul, 597)
# 28           (qa, 88)       (thing, 67)         (devotee, 594)
# 29   (concerning, 87)       (right, 62)          (nature, 594)
#
#                Rigveda     Jewish_bible              Quran   Gurugranthsahib  \
# 0          (veda, 164)    (shall, 7461)        (god, 2891)     (lord, 21718)
# 1          (time, 116)     (lord, 7227)        (lord, 971)      (har, 11183)
# 2          (vedic, 97)     (unto, 6846)         (say, 788)      (guru, 9364)
# 3           (word, 90)     (thou, 4572)        (said, 774)       (hir, 9308)
# 4            (rig, 90)      (thy, 4505)      (people, 684)     (gauvi, 9167)
# 5          (india, 89)     (thee, 3353)         (day, 494)       (gur, 7629)
# 6        (ancient, 81)      (god, 3253)     (believe, 411)      (naam, 7600)
# 7           (text, 79)      (son, 2996)        (know, 390)        (na, 6879)
# 8      (knowledge, 60)     (said, 2901)       (earth, 361)      (true, 6327)
# 9           (life, 57)     (king, 2889)   (messenger, 351)      (awsw, 6167)
# 10         (world, 55)   (israel, 2499)        (come, 276)        (ji, 6107)
# 11       (scholar, 55)       (ye, 2434)        (good, 254)       (god, 5224)
# 12        (indian, 52)      (day, 2122)    (merciful, 251)     (nanak, 5112)
# 13  (civilization, 50)    (house, 1965)      (heaven, 231)    (naanak, 5000)
# 14       (history, 47)   (people, 1904)        (away, 207)      (mwru, 4972)
# 15         (great, 46)     (land, 1879)  (punishment, 204)      (mind, 4947)
# 16         (later, 45)      (man, 1843)        (fear, 189)       (man, 4759)
# 17          (year, 45)     (book, 1781)       (truth, 178)      (nwnk, 4446)
# 18         (today, 44)     (hath, 1758)    (believer, 176)       (bgq, 4433)
# 19          (like, 44)    (child, 1753)       (heart, 174)    (rwmkli, 4265)
# 20         (human, 44)     (hand, 1674)        (sent, 173)        (ky, 3694)
# 21          (vast, 44)     (home, 1672)       (given, 172)      (mehl, 3595)
# 22         (river, 43)      (toc, 1634)        (sign, 171)      (kbir, 3585)
# 23         (power, 42)  (chapter, 1634)        (make, 158)    (mehlaa, 3575)
# 24      (language, 40)     (came, 1567)     (created, 157)      (nwmu, 3390)
# 25           (god, 40)    (shalt, 1485)        (like, 153)        (ki, 3089)
# 26           (day, 40)     (come, 1305)        (used, 149)      (sabh, 2969)
# 27     (tradition, 39)      (men, 1288)    (gracious, 143)  (isrirwgu, 2958)
# 28          (hymn, 38)   (father, 1223)    (revealed, 140)        (jo, 2912)
# 29        (people, 37)     (city, 1129)   (righteous, 140)   (gurmukh, 2852)
#
#              Bible
# 0   (shall, 11258)
# 1     (lord, 8272)
# 2     (thou, 6100)
# 3      (thy, 6038)
# 4      (god, 5226)
# 5     (said, 3950)
# 6     (thee, 3948)
# 7      (son, 3634)
# 8     (king, 3200)
# 9     (hath, 3186)
# 10     (day, 2963)
# 11     (man, 2948)
# 12  (israel, 2590)
# 13   (thing, 2563)
# 14  (people, 2252)
# 15    (hand, 2127)
# 16    (come, 2112)
# 17   (house, 2062)
# 18   (child, 2013)
# 19     (men, 1910)
# 20   (shalt, 1873)
# 21    (land, 1761)
# 22    (came, 1754)
# 23     (let, 1717)
# 24    (word, 1663)
# 25  (father, 1644)
# 26    (city, 1516)
# 27    (went, 1402)
# 28    (hast, 1374)
# 29  (saying, 1332)

# %%
#Top 30 words from including all the books
books_tdm.sum(axis=1).sort_values(ascending=False).head(30)
# Out:
# lord      40302
# shall     21689
# god       17472
# har       11183
# thou      10760
# thy       10682
# man       10041
# guru       9368
# hir        9311
# gauvi      9167
# unto       8691
# said       8123
# gur        7630
# naam       7601
# day        7460
# thee       7409
# na         7316
# son        7194
# king       6801
# true       6601
# awsw       6167
# ji         6107
# come       6011
# mind       5827
# people     5796
# hath       5485
# word       5382
# israel     5133
# nanak      5112
# naanak     5000
# dtype: int64

# %%
#Find Common words in all the 
ind = []
record = []
for index, row in books_tdm.iterrows(): 
    if row.all() > 0:
        ind.append(index)
        record.append(row)
        
books_common_data = pd.DataFrame(record)
books_common_data.head()
# Out:
# books     Bahai_Aqdas  Budhist_Tipitaka  Gita  Rigveda  Jewish_bible  Quran  \
# abide               3                 1     4        1            46     20
# able               12                 3    83        8            95     36
# accept              5                 5   100        3            19     22
# accepted            6                 4    74        1            20     16
# account             3                35    17        9            14     35
#
# books     Gurugranthsahib  Bible
# abide                 185     96
# able                   26    227
# accept                 78     21
# accepted               91     11
# account               189     43

# %%
# Find the top 30 common words from the books
top_dict = {}
for c in books_common_data.columns:
    top = books_common_data[c].sort_values(ascending=False).head(10)
    top_dict[c]= list(zip(top.index,top.values))

top_30_df = pd.DataFrame(top_dict)
top_30_df
# Out:
#        Bahai_Aqdas Budhist_Tipitaka                Gita          Rigveda  \
# 0     (house, 189)      (life, 139)        (book, 1066)      (time, 116)
# 1       (day, 167)     (given, 124)       (right, 1052)       (word, 90)
# 2  (question, 152)      (mind, 105)       (living, 796)    (ancient, 81)
# 3      (book, 139)  (practice, 100)         (body, 771)  (knowledge, 60)
# 4    (people, 130)   (teaching, 96)    (knowledge, 733)       (life, 57)
# 5    (answer, 129)       (rule, 88)         (life, 721)      (world, 55)
# 6     (world, 128)      (order, 86)      (service, 691)      (great, 46)
# 7      (time, 117)  (knowledge, 84)  (translation, 659)       (year, 45)
# 8     (verse, 117)       (view, 81)       (person, 638)       (like, 44)
# 9  (revealed, 101)      (world, 79)         (soul, 597)      (river, 43)
#
#      Jewish_bible              Quran Gurugranthsahib           Bible
# 0     (son, 2996)         (say, 788)    (true, 6327)    (said, 3950)
# 1    (said, 2901)        (said, 774)    (mind, 4947)     (son, 3634)
# 2    (king, 2889)      (people, 684)     (man, 4759)    (king, 3200)
# 3     (day, 2122)         (day, 494)    (love, 2499)     (day, 2963)
# 4   (house, 1965)     (believe, 411)   (world, 2240)     (man, 2948)
# 5  (people, 1904)        (know, 390)    (word, 2142)   (thing, 2563)
# 6    (land, 1879)       (earth, 361)    (come, 2076)  (people, 2252)
# 7     (man, 1843)        (come, 276)  (praise, 2013)    (hand, 2127)
# 8    (book, 1781)        (good, 254)    (body, 1731)    (come, 2112)
# 9   (child, 1753)  (punishment, 204)   (heart, 1686)   (house, 2062)

# %%
# Removing some words which repeats most in all books.
# Filtering most repeated words
# custom_stopwords = ['god','lord','shall']

# books_tdm.drop(index=custom_stopwords, inplace=True)

# %%
#Find unique words in all the books

books_unique_content = {}
for book in books_tdm.columns:
    words = {}
    for index, row in books_tdm.iterrows(): 
        if row[book] > 0 and row[book] == row.sum():
            words[index] = row[book]
    books_unique_content[book] = words

# %%
 books_unique_content.keys()
# Out:
# dict_keys(['Bahai_Aqdas', 'Budhist_Tipitaka', 'Gita', 'Rigveda', 'Jewish_bible', 'Quran', 'Gurugranthsahib', 'Bible'])

# %%
for book in books_unique_content.keys():
    print(book,"==",books_unique_content[book][:50])
    print("####################################################################################")
#     books_unique_content[book] = sorted(books_unique_content[book].items(), key = lambda kv:kv[1], reverse=True)
# Out:
# Bahai_Aqdas == [('effendi', 99), ('shoghi', 99), ('qa', 88), ('ablution', 39), ('aqdas', 31), ('qiblih', 23), ('allglorious', 21), ('ordainer', 16), ('requirement', 16), ('allusion', 15), ('dawningplace', 14), ('gwb', 13), ('behooveth', 12), ('pdc', 12), ('selfsubsisting', 11), ('intercalary', 10), ('remarry', 10), ('reverts', 9), ('antipathy', 8), ('constantinople', 8), ('implementation', 8), ('payable', 8), ('superseded', 8), ('adult', 7), ('allbountiful', 7), ('designate', 7), ('infallibility', 7), ('napoleon', 7), ('wilmette', 7), ('austria', 6), ('branched', 6), ('debar', 6), ('endowment', 6), ('erelong', 6), ('formulated', 6), ('guardianship', 6), ('invalidate', 6), ('legislate', 6), ('monogamy', 6), ('overshadoweth', 6), ('rhine', 6), ('siyyid', 6), ('abjad', 5), ('absolved', 5), ('allpossessing', 5), ('anniversary', 5), ('arson', 5), ('bestbeloved', 5), ('indemnity', 5), ('lotetree', 5)]
# ####################################################################################
# Budhist_Tipitaka == [('sutta', 485), ('dhamma', 167), ('bhikkhu', 136), ('bhikkhus', 129), ('vagga', 81), ('dhammas', 62), ('suttas', 47), ('abhidhamma', 43), ('mindfulness', 41), ('arahatship', 39), ('vinaya', 34), ('suttanta', 28), ('khandhas', 27), ('arahat', 23), ('atta', 23), ('dukkha', 22), ('disciplinary', 19), ('kamma', 18), ('tika', 18), ('citta', 17), ('gotama', 17), ('kassapa', 17), ('magga', 17), ('duka', 16), ('unwholesome', 15), ('volition', 15), ('supernormal', 14), ('practising', 13), ('kosala', 12), ('origination', 12), ('subha', 12), ('vaggas', 12), ('anuruddha', 11), ('dhammapada', 11), ('khandha', 11), ('kusala', 11), ('nissaggiya', 11), ('sacca', 11), ('sunakkhatta', 11), ('almsfood', 10), ('novice', 10), ('pasenadi', 10), ('worldling', 10), ('impermanence', 9), ('khuddaka', 9), ('synod', 9), ('ageing', 8), ('arahats', 8), ('phala', 8), ('theras', 8)]
# ####################################################################################
# Gita == [('bhaktivedanta', 1063), ('intl', 1026), ('tel', 398), ('supersoul', 165), ('fax', 140), ('fruitive', 129), ('opulence', 79), ('demoniac', 70), ('rd', 69), ('bhaktiyoga', 68), ('tu', 66), ('bona', 65), ('fide', 65), ('transcendentalist', 59), ('confidential', 52), ('constitutional', 52), ('mae', 52), ('socalled', 52), ('caitanya', 51), ('api', 48), ('symptom', 47), ('yo', 47), ('aham', 43), ('disciplic', 42), ('tae', 39), ('impersonalists', 38), ('govinda', 36), ('restaurant', 36), ('brahmajyoti', 34), ('paaqar', 34), ('proprietor', 34), ('caiva', 33), ('kmar', 33), ('ovac', 33), ('duryodhana', 32), ('materially', 32), ('plenary', 31), ('ucyate', 31), ('mightyarmed', 30), ('tasya', 30), ('goloka', 29), ('impersonalist', 29), ('individuality', 29), ('perfectional', 29), ('regulative', 29), ('factually', 28), ('karmayoga', 28), ('wv', 28), ('atheistic', 27), ('combination', 27)]
# ####################################################################################
# Rigveda == [('aryan', 26), ('chronology', 22), ('sarasvati', 20), ('hinduism', 17), ('vyasa', 17), ('purus', 15), ('mahabharata', 14), ('upanishad', 14), ('max', 13), ('ecological', 12), ('harappa', 12), ('aurobindo', 11), ('corpus', 11), ('geological', 11), ('indus', 11), ('purusha', 11), ('linguistic', 10), ('dating', 9), ('sutra', 9), ('yagna', 9), ('climate', 8), ('indoeuropean', 8), ('om', 8), ('archaeological', 7), ('artifact', 7), ('computer', 7), ('gangadhar', 7), ('millenia', 7), ('rv', 7), ('vedanga', 7), ('articulated', 6), ('brahmana', 6), ('geology', 6), ('geometry', 6), ('indic', 6), ('mahayuga', 6), ('manvantara', 6), ('polar', 6), ('purana', 6), ('talageri', 6), ('afghanistan', 5), ('archeological', 5), ('archeology', 5), ('incisive', 5), ('indicator', 5), ('linguistics', 5), ('nuance', 5), ('oral', 5), ('psyche', 5), ('relevance', 5)]
# ####################################################################################
# Jewish_bible == [('toc', 1634), ('judah', 818), ('neviim', 719), ('kethuvim', 446), ('joshua', 274), ('jeremiah', 261), ('manasseh', 141), ('shekel', 132), ('hezekiah', 129), ('mealoffering', 126), ('sinoffering', 117), ('gilead', 102), ('ahab', 93), ('jehoshaphat', 84), ('heb', 83), ('peaceofferings', 81), ('bzl', 80), ('selah', 74), ('reuben', 73), ('lebanon', 71), ('aramean', 70), ('canaanite', 68), ('hillcountry', 64), ('shechem', 64), ('zedekiah', 62), ('amorites', 60), ('bashan', 59), ('mordecai', 58), ('nebuchadnezzar', 54), ('haman', 53), ('josiah', 53), ('midian', 52), ('zadok', 52), ('jehoiada', 51), ('naphtali', 50), ('rehoboam', 50), ('balak', 49), ('builded', 49), ('joash', 49), ('wroth', 49), ('harlotry', 48), ('hittite', 48), ('azariah', 46), ('ephah', 45), ('netherworld', 45), ('sarah', 45), ('zebulun', 45), ('korah', 44), ('asher', 43), ('micah', 43)]
# ####################################################################################
# Quran == [('warner', 48), ('disbelief', 34), ('imran', 33), ('livestock', 30), ('hud', 27), ('polytheist', 25), ('thamood', 25), ('albaqarah', 24), ('appreciative', 21), ('ridicule', 20), ('wrongdoing', 20), ('meem', 17), ('alaraf', 16), ('annisa', 16), ('taha', 16), ('ali', 15), ('alanam', 14), ('lam', 13), ('almaidah', 12), ('attawbah', 12), ('envoy', 12), ('repel', 12), ('yaseen', 12), ('denier', 11), ('luqman', 10), ('median', 10), ('qaf', 10), ('alisra', 9), ('annahl', 9), ('ashshuara', 9), ('desertarabs', 9), ('differed', 9), ('indecency', 9), ('messiah', 9), ('mobilize', 9), ('reprieved', 9), ('saleh', 9), ('shuaib', 9), ('yunus', 9), ('yusuf', 9), ('aligners', 8), ('alkahf', 8), ('clot', 8), ('fabricate', 8), ('stingy', 8), ('suffices', 8), ('alahzab', 7), ('alanbiya', 7), ('alhajj', 7), ('almuminun', 7)]
# ####################################################################################
# Gurugranthsahib == [('har', 11183), ('gauvi', 9167), ('awsw', 6167), ('ji', 6107), ('nanak', 5112), ('naanak', 5000), ('mwru', 4972), ('nwnk', 4446), ('bgq', 4433), ('rwmkli', 4265), ('ky', 3694), ('mehl', 3595), ('kbir', 3585), ('mehlaa', 3575), ('nwmu', 3390), ('sabh', 2969), ('isrirwgu', 2958), ('jo', 2912), ('gurmukh', 2852), ('parabh', 2778), ('rahaao', 2685), ('rhwau', 2685), ('mhlw', 2631), ('mwj', 2616), ('sorit', 2578), ('kee', 2562), ('satgur', 2552), ('iblwvlu', 2547), ('suhi', 2534), ('qy', 2474), ('raam', 2215), ('byrau', 2107), ('kaa', 2019), ('shabad', 2002), ('kw', 1979), ('sukmni', 1971), ('kar', 1915), ('swrmg', 1914), ('slok', 1788), ('kai', 1787), ('jan', 1777), ('aap', 1770), ('rwm', 1758), ('awpy', 1701), ('sabad', 1667), ('aapay', 1655), ('tay', 1619), ('gurmuik', 1615), ('hoay', 1602), ('prb', 1598)]
# ####################################################################################
# Bible == [('shew', 257), ('jeremias', 235), ('josue', 215), ('sion', 184), ('pharao', 182), ('peter', 169), ('simon', 154), ('manasses', 142), ('galaad', 136), ('mayst', 126), ('isaias', 122), ('ezechias', 116), ('nabuchodonosor', 110), ('judea', 105), ('syria', 103), ('elia', 102), ('chanaan', 101), ('pharisee', 101), ('tobias', 96), ('josaphat', 86), ('achab', 84), ('paralipomenon', 83), ('shewed', 82), ('sicles', 80), ('suburb', 80), ('ruben', 74), ('libanus', 73), ('machabees', 73), ('ezechiel', 72), ('canticle', 67), ('libation', 66), ('sedecias', 65), ('antiochus', 64), ('azarias', 64), ('shewn', 64), ('joas', 61), ('syrian', 61), ('eliseus', 60), ('cherubims', 58), ('ecclesiasticus', 58), ('violet', 56), ('zacharias', 56), ('duke', 55), ('sadoc', 55), ('baptized', 54), ('josias', 54), ('mardochai', 54), ('pilate', 54), ('sichem', 53), ('demetrius', 51)]
# ####################################################################################

# %%
books_unique_content
# Out:
# {'Bahai_Aqdas': [('effendi', 99),
#   ('shoghi', 99),
#   ('qa', 88),
#   ('ablution', 39),
#   ('aqdas', 31),
#   ('qiblih', 23),
#   ('allglorious', 21),
#   ('ordainer', 16),
#   ('requirement', 16),
#   ('allusion', 15),
#   ('dawningplace', 14),
#   ('gwb', 13),
#   ('behooveth', 12),
#   ('pdc', 12),
#   ('selfsubsisting', 11),
#   ('intercalary', 10),
#   ('remarry', 10),
#   ('reverts', 9),
#   ('antipathy', 8),
#   ('constantinople', 8),
#   ('implementation', 8),
#   ('payable', 8),
#   ('superseded', 8),
#   ('adult', 7),
#   ('allbountiful', 7),
#   ('designate', 7),
#   ('infallibility', 7),
#   ('napoleon', 7),
#   ('wilmette', 7),
#   ('austria', 6),
#   ('branched', 6),
#   ('debar', 6),
#   ('endowment', 6),
#   ('erelong', 6),
#   ('formulated', 6),
#   ('guardianship', 6),
#   ('invalidate', 6),
#   ('legislate', 6),
#   ('monogamy', 6),
#   ('overshadoweth', 6),
#   ('rhine', 6),
#   ('siyyid', 6),
#   ('abjad', 5),
#   ('absolved', 5),
#   ('allpossessing', 5),
#   ('anniversary', 5),
#   ('arson', 5),
#   ('bestbeloved', 5),
#   ('indemnity', 5),
#   ('lotetree', 5),
#   ('mendicancy', 5),
#   ('ordaineth', 5),
#   ('unsaid', 5),
#   ('varies', 5),
#   ('abrogates', 4),
#   ('adrianople', 4),
#   ('allpraised', 4),
#   ('antecedent', 4),
#   ('behest', 4),
#   ('clamor', 4),
#   ('conformity', 4),
#   ('dawnbreakers', 4),
#   ('deduction', 4),
#   ('disputation', 4),
#   ('divinely', 4),
#   ('edn', 4),
#   ('expended', 4),
#   ('formally', 4),
#   ('insecure', 4),
#   ('interment', 4),
#   ('interpreteth', 4),
#   ('interred', 4),
#   ('intestacy', 4),
#   ('parliament', 4),
#   ('prophetic', 4),
#   ('revolutionizing', 4),
#   ('sifter', 4),
#   ('trustworthiness', 4),
#   ('unconstrained', 4),
#   ('unsealed', 4),
#   ('vernal', 4),
#   ('vicegerency', 4),
#   ('abrogated', 3),
#   ('absolution', 3),
#   ('aforementioned', 3),
#   ('alcohol', 3),
#   ('alluded', 3),
#   ('anticipation', 3),
#   ('applieth', 3),
#   ('arriveth', 3),
#   ('asserts', 3),
#   ('awaiteth', 3),
#   ('beseemeth', 3),
#   ('betrothal', 3),
#   ('biddeth', 3),
#   ('charter', 3),
#   ('compensating', 3),
#   ('counseleth', 3),
#   ('dawningplaces', 3),
#   ('drastic', 3),
#   ('educate', 3),
#   ('elaborates', 3),
#   ('enforced', 3),
#   ('envisages', 3),
#   ('everabiding', 3),
#   ('exceeds', 3),
#   ('exempts', 3),
#   ('exposure', 3),
#   ('francis', 3),
#   ('gauged', 3),
#   ('halfbrothers', 3),
#   ('halfsisters', 3),
#   ('hashish', 3),
#   ('heedlessness', 3),
#   ('istanbul', 3),
#   ('justness', 3),
#   ('matrimony', 3),
#   ('mutandis', 3),
#   ('mutatis', 3),
#   ('nakhuds', 3),
#   ('omitted', 3),
#   ('ottoman', 3),
#   ('overstep', 3),
#   ('pardoner', 3),
#   ('polygamy', 3),
#   ('pp', 3),
#   ('preclude', 3),
#   ('promissory', 3),
#   ('quaffed', 3),
#   ('remarrying', 3),
#   ('sable', 3),
#   ('seateth', 3),
#   ('trim', 3),
#   ('uncleanliness', 3),
#   ('unerring', 3),
#   ('vicegerent', 3),
#   ('wafted', 3),
#   ('wob', 3),
#   ('abrogate', 2),
#   ('abrogation', 2),
#   ('accrueth', 2),
#   ('acquireth', 2),
#   ('allbounteous', 2),
#   ('allhighest', 2),
#   ('allowable', 2),
#   ('alludes', 2),
#   ('april', 2),
#   ('archbreaker', 2),
#   ('aries', 2),
#   ('arsonist', 2),
#   ('attacheth', 2),
#   ('beaver', 2),
#   ('beggeth', 2),
#   ('bestowal', 2),
#   ('betide', 2),
#   ('bide', 2),
#   ('bigamy', 2),
#   ('chapel', 2),
#   ('clv', 2),
#   ('coincides', 2),
#   ('commence', 2),
#   ('commencement', 2),
#   ('comport', 2),
#   ('conscientious', 2),
#   ('contenteth', 2),
#   ('contingent', 2),
#   ('counseled', 2),
#   ('customarily', 2),
#   ('dais', 2),
#   ('deciding', 2),
#   ('deference', 2),
#   ('defrayed', 2),
#   ('dependable', 2),
#   ('depreciation', 2),
#   ('deterred', 2),
#   ('devolves', 2),
#   ('diffuseth', 2),
#   ('dumbfounded', 2),
#   ('durable', 2),
#   ('elucidate', 2),
#   ('embraceth', 2),
#   ('embryonic', 2),
#   ('enfolded', 2),
#   ('eschew', 2),
#   ('esw', 2),
#   ('eventual', 2),
#   ('exclaiming', 2),
#   ('exemplify', 2),
#   ('expiration', 2),
#   ('expounder', 2),
#   ('faithlessly', 2),
#   ('francoprussian', 2),
#   ('frugality', 2),
#   ('fulllength', 2),
#   ('fundamentally', 2),
#   ('halfbrother', 2),
#   ('homosexual', 2),
#   ('illumine', 2),
#   ('implemented', 2),
#   ('inadmissible', 2),
#   ('inculcates', 2),
#   ('induceth', 2),
#   ('indulgent', 2),
#   ('informeth', 2),
#   ('inseparability', 2),
#   ('instability', 2),
#   ('instigation', 2),
#   ('interdiction', 2),
#   ('intimation', 2),
#   ('intrigue', 2),
#   ('inviolable', 2),
#   ('irrevocable', 2),
#   ('judicial', 2),
#   ('kaiser', 2),
#   ('kindliness', 2),
#   ('lauded', 2),
#   ('legitimacy', 2),
#   ('legitimately', 2),
#   ('lottery', 2),
#   ('loyalty', 2),
#   ('lxxii', 2),
#   ('malodorous', 2),
#   ('mandatory', 2),
#   ('martyrdom', 2),
#   ('noteworthy', 2),
#   ('occurreth', 2),
#   ('organic', 2),
#   ('peruse', 2),
#   ('pettiness', 2),
#   ('plunging', 2),
#   ('powerlessness', 2),
#   ('preamble', 2),
#   ('promulgation', 2),
#   ('prussia', 2),
#   ('refund', 2),
#   ('refuting', 2),
#   ('reiterated', 2),
#   ('representeth', 2),
#   ('reprinted', 2),
#   ('repudiate', 2),
#   ('resignation', 2),
#   ('reunion', 2),
#   ('reverteth', 2),
#   ('revolutionized', 2),
#   ('rigor', 2),
#   ('ritually', 2),
#   ('sluggishness', 2),
#   ('sodomy', 2),
#   ('solemnly', 2),
#   ('squirrel', 2),
#   ('stealthily', 2),
#   ('subtracted', 2),
#   ('summoneth', 2),
#   ('sundown', 2),
#   ('tact', 2),
#   ('traditionally', 2),
#   ('trove', 2),
#   ('unapproachably', 2),
#   ('unavailable', 2),
#   ('underline', 2),
#   ('undoubted', 2),
#   ('unravel', 2),
#   ('unworn', 2),
#   ('valor', 2),
#   ('vassal', 2),
#   ('vindicate', 2),
#   ('warneth', 2),
#   ('weightiest', 2),
#   ('wellfavored', 2),
#   ('xx', 2),
#   ('xxi', 2),
#   ('xxii', 2),
#   ('abbreviation', 1),
#   ('abeyance', 1),
#   ('abolition', 1),
#   ('abovecited', 1),
#   ('abovenoted', 1),
#   ('abrogating', 1),
#   ('absolve', 1),
#   ('absolveth', 1),
#   ('abstention', 1),
#   ('absurdity', 1),
#   ('accent', 1),
#   ('achieveth', 1),
#   ('admonishes', 1),
#   ('admonisheth', 1),
#   ('adornings', 1),
#   ('advocacy', 1),
#   ('aegis', 1),
#   ('affectation', 1),
#   ('affecting', 1),
#   ('agelong', 1),
#   ('alcove', 1),
#   ('allcompelling', 1),
#   ('allembracing', 1),
#   ('allgracious', 1),
#   ('allimportant', 1),
#   ('allocation', 1),
#   ('allperceiving', 1),
#   ('allsubduing', 1),
#   ('amazeth', 1),
#   ('annotated', 1),
#   ('annotation', 1),
#   ('annually', 1),
#   ('answerer', 1),
#   ('antique', 1),
#   ('appellation', 1),
#   ('appoints', 1),
#   ('apprised', 1),
#   ('appropriated', 1),
#   ('approximately', 1),
#   ('aprilmay', 1),
#   ('archery', 1),
#   ('arriving', 1),
#   ('artery', 1),
#   ('ascendancy', 1),
#   ('ascribing', 1),
#   ('ashkhabad', 1),
#   ('assassination', 1),
#   ('assemblage', 1),
#   ('assessable', 1),
#   ('assiduous', 1),
#   ('assigning', 1),
#   ('astronomically', 1),
#   ('attest', 1),
#   ('attesteth', 1),
#   ('attracteth', 1),
#   ('august', 1),
#   ('availing', 1),
#   ('avowal', 1),
#   ('awarding', 1),
#   ('ballot', 1),
#   ('bathhouse', 1),
#   ('beamed', 1),
#   ('beaming', 1),
#   ('befouled', 1),
#   ('behoof', 1),
#   ('bequeath', 1),
#   ('betokeneth', 1),
#   ('betokening', 1),
#   ('betting', 1),
#   ('bewaileth', 1),
#   ('bingo', 1),
#   ('blest', 1),
#   ('boileth', 1),
#   ('bosporus', 1),
#   ('bounteousness', 1),
#   ('brideprice', 1),
#   ('brightest', 1),
#   ('broadest', 1),
#   ('byzantium', 1),
#   ('caliph', 1),
#   ('caliphate', 1),
#   ('cannabis', 1),
#   ('casket', 1),
#   ('categorically', 1),
#   ('cavil', 1),
#   ('centenary', 1),
#   ('charger', 1),
#   ('christendom', 1),
#   ('circa', 1),
#   ('circled', 1),
#   ('circling', 1),
#   ('circumambulate', 1),
#   ('citadel', 1),
#   ('citeth', 1),
#   ('clandestinely', 1),
#   ('cleric', 1),
#   ('clxvi', 1),
#   ('clxvii', 1),
#   ('clxxxi', 1),
#   ('clxxxii', 1),
#   ('clxxxiii', 1),
#   ('coarser', 1),
#   ('coincide', 1),
#   ('coinciding', 1),
#   ('commemorated', 1),
#   ('commemorates', 1),
#   ('commenced', 1),
#   ('commenceth', 1),
#   ('compliance', 1),
#   ('comprehendeth', 1),
#   ('conciliation', 1),
#   ('conciseness', 1),
#   ('confronts', 1),
#   ('connotation', 1),
#   ('conscientiously', 1),
#   ('constituteth', 1),
#   ('contenting', 1),
#   ('converseth', 1),
#   ('correspondeth', 1),
#   ('correspondingly', 1),
#   ('corresponds', 1),
#   ('courteous', 1),
#   ('crossreference', 1),
#   ('crosssection', 1),
#   ('cubic', 1),
#   ('cupful', 1),
#   ('cv', 1),
#   ('cxvii', 1),
#   ('dareth', 1),
#   ('dawntide', 1),
#   ('debarred', 1),
#   ('debaseth', 1),
#   ('deducted', 1),
#   ('deign', 1),
#   ('deleterious', 1),
#   ('delimit', 1),
#   ('demeanor', 1),
#   ('denoteth', 1),
#   ('depravity', 1),
#   ('deranges', 1),
#   ('designedly', 1),
#   ('despondency', 1),
#   ('devolveth', 1),
#   ('diffuser', 1),
#   ('disagrees', 1),
#   ('disapprove', 1),
#   ('disclaims', 1),
#   ('discolored', 1),
#   ('discoverer', 1),
#   ('disdainful', 1),
#   ('disintegration', 1),
#   ('disparity', 1),
#   ('dissertation', 1),
#   ('distractedly', 1),
#   ('donned', 1),
#   ('downloaded', 1),
#   ('ebbed', 1),
#   ('ecclesiastic', 1),
#   ('ecclesiastical', 1),
#   ('educateth', 1),
#   ('elapse', 1),
#   ('elegance', 1),
#   ('elucidates', 1),
#   ('embeds', 1),
#   ('embodying', 1),
#   ('emotive', 1),
#   ('encumber', 1),
#   ('endorsed', 1),
#   ('endorsement', 1),
#   ('endoweth', 1),
#   ('enforce', 1),
#   ('enricheth', 1),
#   ('entitlement', 1),
#   ('entitling', 1),
#   ('entreats', 1),
#   ('enunciation', 1),
#   ('envisage', 1),
#   ('especial', 1),
#   ('estrangement', 1),
#   ('ethereal', 1),
#   ('eulogizes', 1),
#   ('evanescent', 1),
#   ('eventuality', 1),
#   ('everbounteous', 1),
#   ('evidenceth', 1),
#   ('exalting', 1),
#   ('excursion', 1),
#   ('exemplar', 1),
#   ('exhorts', 1),
#   ('existeth', 1),
#   ('explanatory', 1),
#   ('expoundeth', 1),
#   ('extenuating', 1),
#   ('extolleth', 1),
#   ('extramarital', 1),
#   ('extrapolating', 1),
#   ('facilitates', 1),
#   ('fanatical', 1),
#   ('farremoved', 1),
#   ('fasteneth', 1),
#   ('fatherhood', 1),
#   ('football', 1),
#   ('footnote', 1),
#   ('forestall', 1),
#   ('formulates', 1),
#   ('franz', 1),
#   ('friedrich', 1),
#   ('garb', 1),
#   ('generality', 1),
#   ('geometrical', 1),
#   ('glossary', 1),
#   ('gracefulness', 1),
#   ('grapple', 1),
#   ('greeteth', 1),
#   ('habitforming', 1),
#   ('habituated', 1),
#   ('hairsplitting', 1),
#   ('hallucinogenic', 1),
#   ('handicapped', 1),
#   ('headdress', 1),
#   ('heavenwards', 1),
#   ('heralded', 1),
#   ('heroin', 1),
#   ('homemaking', 1),
#   ('homosexuality', 1),
#   ('hooting', 1),
#   ('humanitarian', 1),
#   ('ignominiously', 1),
#   ('immersion', 1),
#   ('imprinteth', 1),
#   ('indexing', 1),
#   ('indicateth', 1),
#   ('indissolubly', 1),
#   ('inescapable', 1),
#   ('infrequent', 1),
#   ('infringe', 1),
#   ('injureth', 1),
#   ('inkling', 1),
#   ('inordinately', 1),
#   ('insecurity', 1),
#   ('insinuation', 1),
#   ('instituting', 1),
#   ('integer', 1),
#   ('integration', 1),
#   ('interpretive', 1),
#   ('intimated', 1),
#   ('intransigence', 1),
#   ('intrigued', 1),
#   ('introductory', 1),
#   ('invalidated', 1),
#   ('invalidateth', 1),
#   ('inviolate', 1),
#   ('invokest', 1),
#   ('irrevocably', 1),
#   ('ivd', 1),
#   ('january', 1),
#   ('josef', 1),
#   ('kilometer', 1),
#   ('kurr', 1),
#   ('languor', 1),
#   ('lassitude', 1),
#   ('leagued', 1),
#   ('legislative', 1),
#   ('limiting', 1),
#   ('lineal', 1),
#   ('listeneth', 1),
#   ('literalness', 1),
#   ('longlost', 1),
#   ('lovingprovidence', 1),
#   ('lsd', 1),
#   ('ludwig', 1),
#   ('lvi', 1),
#   ('lxx', 1),
#   ('lxxi', 1),
#   ('markedly', 1),
#   ('marksmanship', 1),
#   ('marmara', 1),
#   ('matchless', 1),
#   ('meantime', 1),
#   ('melodiously', 1),
#   ('mendicity', 1),
#   ('menstruating', 1),
#   ('metaphysical', 1),
#   ('midmost', 1),
#   ('midpoint', 1),
#   ('milieu', 1),
#   ('modify', 1),
#   ('moldering', 1),
#   ('muskladen', 1),
#   ('najaf', 1),
#   ('necessitated', 1),
#   ('negligible', 1),
#   ('nightingale', 1),
#   ('nineteenday', 1),
#   ('nominated', 1),
#   ('nonarabicspeaking', 1),
#   ('nonobligatory', 1),
#   ('norm', 1),
#   ('notation', 1),
#   ('ominously', 1),
#   ('omission', 1),
#   ('operate', 1),
#   ('oppressively', 1),
#   ('ordination', 1),
#   ('orthodoxy', 1),
#   ('ostentatiously', 1),
#   ('overaccumulation', 1),
#   ('overview', 1),
#   ('palpable', 1),
#   ('peacekeeping', 1),
#   ('pederasty', 1),
#   ('penalizing', 1),
#   ('perpetration', 1),
#   ('persisteth', 1),
#   ('perusal', 1),
#   ('perused', 1),
#   ('pervadeth', 1),
#   ('petrify', 1),
#   ('peyote', 1),
#   ('photograph', 1),
#   ('pivot', 1),
#   ('placeless', 1),
#   ('politeness', 1),
#   ('portal', 1),
#   ('posthumously', 1),
#   ('practicable', 1),
#   ('precipitated', 1),
#   ('precludes', 1),
#   ('predate', 1),
#   ('predeceases', 1),
#   ('premeditated', 1),
#   ('prerequisite', 1),
#   ('presumably', 1),
#   ('presuppose', 1),
#   ('primogeniture', 1),
#   ('prisoncity', 1),
#   ('privileged', 1),
#   ('proffering', 1),
#   ('promoting', 1),
#   ('pronouncement', 1),
#   ('pronounces', 1),
#   ('propitious', 1),
#   ('protectorship', 1),
#   ('provisional', 1),
#   ('pulsate', 1),
#   ('quaff', 1),
#   ('qualify', 1),
#   ('quickener', 1),
#   ('quoting', 1),
#   ('radical', 1),
#   ('ranked', 1),
#   ('readjustment', 1),
#   ('realizeth', 1),
#   ('reallocated', 1),
#   ('reciteth', 1),
#   ('recognizeth', 1),
#   ('recommence', 1),
#   ('reconsideration', 1),
#   ('recuperation', 1),
#   ('recur', 1),
#   ('refulgent', 1),
#   ('refunded', 1),
#   ('regional', 1),
#   ('registry', 1),
#   ('reintroducing', 1),
#   ('reinvigorate', 1),
#   ('reiterates', 1),
#   ('reiterating', 1),
#   ('remarriage', 1),
#   ('reminiscent', 1),
#   ('remoteness', 1),
#   ('repeal', 1),
#   ('reprehensible', 1),
#   ('republished', 1),
#   ('repudiation', 1),
#   ('repugnance', 1),
#   ('retaliatory', 1),
#   ('ronald', 1),
#   ('rove', 1),
#   ('safeguarded', 1),
#   ('savoreth', 1),
#   ('scrutiny', 1),
#   ('seaport', 1),
#   ('secondeldest', 1),
#   ('sedan', 1),
#   ('selfappointed', 1),
#   ('selfeffacement', 1),
#   ('selfprotection', 1),
#   ('sequentially', 1),
#   ('seventeenthcentury', 1),
#   ('shortfall', 1),
#   ('shrouding', 1),
#   ('signalized', 1),
#   ('slumbering', 1),
#   ('snowwhite', 1),
#   ('societal', 1),
#   ('spiritualizing', 1),
#   ('steamship', 1),
#   ('stimulus', 1),
#   ('streamed', 1),
#   ('stringently', 1),
#   ('structural', 1),
#   ('styled', 1),
#   ('submissiveness', 1),
#   ('successorship', 1),
#   ('succinctly', 1),
#   ('suffused', 1),
#   ('sullied', 1),
#   ('summoner', 1),
#   ('summoning', 1),
#   ('superb', 1),
#   ('supplicating', 1),
#   ('surgeth', 1),
#   ('susceptible', 1),
#   ('symbolically', 1),
#   ('synthesizes', 1),
#   ('tactful', 1),
#   ('tenacity', 1),
#   ('terseness', 1),
#   ('threestage', 1),
#   ('throbbing', 1),
#   ('timely', 1),
#   ('timepiece', 1),
#   ('tragic', 1),
#   ('transcriber', 1),
#   ('transmutation', 1),
#   ('transpiring', 1),
#   ('turkey', 1),
#   ('twelveday', 1),
#   ('twentyfourhour', 1),
#   ('unanimity', 1),
#   ('unassailable', 1),
#   ('uncluttered', 1),
#   ('unfolding', 1),
#   ('unfoldment', 1),
#   ('unhygienic', 1),
#   ('unintentionally', 1),
#   ('unlock', 1),
#   ('unlocked', 1),
#   ('unnumbered', 1),
#   ('unreserved', 1),
#   ('unused', 1),
#   ('unveils', 1),
#   ('upliftment', 1),
#   ('utilitarian', 1),
#   ('vacillate', 1),
#   ('vainglorious', 1),
#   ('variant', 1),
#   ('vaunting', 1),
#   ('venerated', 1),
#   ('verbally', 1),
#   ('versailles', 1),
#   ('vindication', 1),
#   ('violateth', 1),
#   ('visibly', 1),
#   ('vitally', 1),
#   ('vowing', 1),
#   ('waft', 1),
#   ('wafting', 1),
#   ('warbling', 1),
#   ('weakening', 1),
#   ('weal', 1),
#   ('welltodo', 1),
#   ('willful', 1),
#   ('wwwbahaiorglegal', 1),
#   ('xcvii', 1),
#   ('xxiii', 1),
#   ('xxix', 1),
#   ('xxv', 1),
#   ('xxvi', 1),
#   ('xxvii', 1),
#   ('xxx', 1),
#   ('xxxi', 1),
#   ('xxxii', 1),
#   ('xxxvii', 1),
#   ('xxxviii', 1)],
#  'Budhist_Tipitaka': [('sutta', 485),
#   ('dhamma', 167),
#   ('bhikkhu', 136),
#   ('bhikkhus', 129),
#   ('vagga', 81),
#   ('dhammas', 62),
#   ('suttas', 47),
#   ('abhidhamma', 43),
#   ('mindfulness', 41),
#   ('arahatship', 39),
#   ('vinaya', 34),
#   ('suttanta', 28),
#   ('khandhas', 27),
#   ('arahat', 23),
#   ('atta', 23),
#   ('dukkha', 22),
#   ('disciplinary', 19),
#   ('kamma', 18),
#   ('tika', 18),
#   ('citta', 17),
#   ('gotama', 17),
#   ('kassapa', 17),
#   ('magga', 17),
#   ('duka', 16),
#   ('unwholesome', 15),
#   ('volition', 15),
#   ('supernormal', 14),
#   ('practising', 13),
#   ('kosala', 12),
#   ('origination', 12),
#   ('subha', 12),
#   ('vaggas', 12),
#   ('anuruddha', 11),
#   ('dhammapada', 11),
#   ('khandha', 11),
#   ('kusala', 11),
#   ('nissaggiya', 11),
#   ('sacca', 11),
#   ('sunakkhatta', 11),
#   ('almsfood', 10),
#   ('novice', 10),
#   ('pasenadi', 10),
#   ('worldling', 10),
#   ('impermanence', 9),
#   ('khuddaka', 9),
#   ('synod', 9),
#   ('ageing', 8),
#   ('arahats', 8),
#   ('phala', 8),
#   ('theras', 8),
#   ('uninstructed', 8),
#   ('aniyata', 7),
#   ('bodhisatta', 7),
#   ('buddhahood', 7),
#   ('corporeality', 7),
#   ('enumeration', 7),
#   ('paccayas', 7),
#   ('yamaka', 7),
#   ('akusala', 6),
#   ('anatta', 6),
#   ('anicca', 6),
#   ('ariyas', 6),
#   ('dukas', 6),
#   ('indriya', 6),
#   ('lifespan', 6),
#   ('paccaya', 6),
#   ('paccekabuddha', 6),
#   ('skylark', 6),
#   ('streamwinner', 6),
#   ('thera', 6),
#   ('tikas', 6),
#   ('vatthu', 6),
#   ('bhaddekaratta', 5),
#   ('bhikkhuhood', 5),
#   ('corporeal', 5),
#   ('cunda', 5),
#   ('demeritorious', 5),
#   ('devadaha', 5),
#   ('ekaka', 5),
#   ('kasi', 5),
#   ('madhura', 5),
#   ('majjhima', 5),
#   ('millionaire', 5),
#   ('niddesa', 5),
#   ('practises', 5),
#   ('saccaka', 5),
#   ('sakka', 5),
#   ('sandaka', 5),
#   ('stanza', 5),
#   ('sumedha', 5),
#   ('udena', 5),
#   ('vacchagotta', 5),
#   ('accruing', 4),
#   ('anuloma', 4),
#   ('anupada', 4),
#   ('arahatta', 4),
#   ('ardently', 4),
#   ('ariya', 4),
#   ('bhadraka', 4),
#   ('birthstories', 4),
#   ('bodhi', 4),
#   ('burma', 4),
#   ('concluding', 4),
#   ('deathbed', 4),
#   ('disenchanted', 4),
#   ('disenchantment', 4),
#   ('homelessness', 4),
#   ('kapilavatthu', 4),
#   ('khemaka', 4),
#   ('magadha', 4),
#   ('maghadeva', 4),
#   ('milinda', 4),
#   ('netti', 4),
#   ('nutriment', 4),
#   ('petas', 4),
#   ('potaliya', 4),
#   ('restlessness', 4),
#   ('sakyan', 4),
#   ('sekhiya', 4),
#   ('uposatha', 4),
#   ('vakkali', 4),
#   ('villager', 4),
#   ('vitakka', 4),
#   ('catechism', 3),
#   ('classed', 3),
#   ('classifying', 3),
#   ('compiling', 3),
#   ('dasuttara', 3),
#   ('devotes', 3),
#   ('dhammacakkappavattana', 3),
#   ('donor', 3),
#   ('fostermother', 3),
#   ('gahapati', 3),
#   ('hetus', 3),
#   ('homelife', 3),
#   ('iddhi', 3),
#   ('insightknowledge', 3),
#   ('insubstantiality', 3),
#   ('interview', 3),
#   ('isigili', 3),
#   ('itivuttaka', 3),
#   ('janavasabha', 3),
#   ('kandaraka', 3),
#   ('khattiya', 3),
#   ('manual', 3),
#   ('nondecline', 3),
#   ('orthodox', 3),
#   ('paramattha', 3),
#   ('penetrative', 3),
#   ('peta', 3),
#   ('polite', 3),
#   ('procedural', 3),
#   ('quintessence', 3),
#   ('rainsresidence', 3),
#   ('refuted', 3),
#   ('sentient', 3),
#   ('suddhodana', 3),
#   ('supramundane', 3),
#   ('synthetical', 3),
#   ('trifling', 3),
#   ('unsatisfactoriness', 3),
#   ('upakkilesa', 3),
#   ('vekhanasa', 3),
#   ('volitional', 3),
#   ('abandonment', 2),
#   ('abstemious', 2),
#   ('abstruse', 2),
#   ('acceded', 2),
#   ('accuses', 2),
#   ('adhicitta', 2),
#   ('aggivaccha', 2),
#   ('akkosaka', 2),
#   ('analyse', 2),
#   ('arahato', 2),
#   ('assapura', 2),
#   ('balas', 2),
#   ('barristeratlaw', 2),
#   ('bhagavato', 2),
#   ('bhagga', 2),
#   ('bhayabherava', 2),
#   ('biographical', 2),
#   ('blameworthy', 2),
#   ('bodhipakkhiya', 2),
#   ('brahmanimantanika', 2),
#   ('bsc', 2),
#   ('burmese', 2),
#   ('cakkavatti', 2),
#   ('canonical', 2),
#   ('catukka', 2),
#   ('cetokhila', 2),
#   ('cetovimutti', 2),
#   ('chabbisodhana', 2),
#   ('chachakka', 2),
#   ('chakka', 2),
#   ('channa', 2),
#   ('conditionality', 2),
#   ('confesses', 2),
#   ('confidenceinspiring', 2),
#   ('criticized', 2),
#   ('dasaka', 2),
#   ('defining', 2),
#   ('delightfully', 2),
#   ('devadattas', 2),
#   ('dhammacetiya', 2),
#   ('discerns', 2),
#   ('dukaduka', 2),
#   ('dukatika', 2),
#   ('dyad', 2),
#   ('editorial', 2),
#   ('enquiry', 2),
#   ('enumerates', 2),
#   ('exegetical', 2),
#   ('facilitate', 2),
#   ('favouritism', 2),
#   ('frantic', 2),
#   ('glade', 2),
#   ('gotta', 2),
#   ('graduated', 2),
#   ('grouping', 2),
#   ('headman', 2),
#   ('hoti', 2),
#   ('imperturbable', 2),
#   ('incorporated', 2),
#   ('indefinite', 2),
#   ('indeterminate', 2),
#   ('indifference', 2),
#   ('inordinate', 2),
#   ('intensely', 2),
#   ('irremediable', 2),
#   ('jayasena', 2),
#   ('kappa', 2),
#   ('kappina', 2),
#   ('kimila', 2),
#   ('kinti', 2),
#   ('kosambiya', 2),
#   ('kukkuravatika', 2),
#   ('lohicca', 2),
#   ('maligning', 2),
#   ('mallas', 2),
#   ('maung', 2),
#   ('metta', 2),
#   ('mindobjects', 2),
#   ('moggaliputtatissa', 2),
#   ('monastic', 2),
#   ('myint', 2),
#   ('myo', 2),
#   ('nadir', 2),
#   ('nagaravindeyya', 2),
#   ('nandiya', 2),
#   ('navaka', 2),
#   ('nikkhepa', 2),
#   ('nirodha', 2),
#   ('nonconsciousness', 2),
#   ('nonhumans', 2),
#   ('nonreturner', 2),
#   ('nothingness', 2),
#   ('obstructs', 2),
#   ('oncereturner', 2),
#   ('opamma', 2),
#   ('paccekabuddhas', 2),
#   ('paritta', 2),
#   ('pitaka', 2),
#   ('piya', 2),
#   ('probationary', 2),
#   ('purposely', 2),
#   ('rangoon', 2),
#   ('realizable', 2),
#   ('recognised', 2),
#   ('remediable', 2),
#   ('repays', 2),
#   ('resented', 2),
#   ('retd', 2),
#   ('reviles', 2),
#   ('rohitassa', 2),
#   ('roofing', 2),
#   ('sahetuka', 2),
#   ('sakyans', 2),
#   ('sallekha', 2),
#   ('salvaged', 2),
#   ('sammuti', 2),
#   ('sappurisa', 2),
#   ('sassata', 2),
#   ('sattaka', 2),
#   ('sattaloka', 2),
#   ('sceptical', 2),
#   ('sekha', 2),
#   ('selfenlightened', 2),
#   ('selflessness', 2),
#   ('spurious', 2),
#   ('sudda', 2),
#   ('suddha', 2),
#   ('susima', 2),
#   ('tassa', 2),
#   ('tevijja', 2),
#   ('tevijjavaccha', 2),
#   ('tikaduka', 2),
#   ('tikatika', 2),
#   ('todeyya', 2),
#   ('tour', 2),
#   ('udumbarika', 2),
#   ('unharmed', 2),
#   ('unpolluted', 2),
#   ('unruffled', 2),
#   ('uraga', 2),
#   ('vammika', 2),
#   ('vanapattha', 2),
#   ('vassa', 2),
#   ('vattha', 2),
#   ('vepulla', 2),
#   ('vessa', 2),
#   ('vicepresident', 2),
#   ('vide', 2),
#   ('vinicchaya', 2),
#   ('yasa', 2),
#   ('zenith', 2),
#   ('abstruseness', 1),
#   ('abusive', 1),
#   ('accessory', 1),
#   ('acchariyaabbhuta', 1),
#   ('acchindana', 1),
#   ('acid', 1),
#   ('aciravata', 1),
#   ('acme', 1),
#   ('adept', 1),
#   ('adhiccasamuppanna', 1),
#   ('adukkhamasukha', 1),
#   ('adverse', 1),
#   ('aeon', 1),
#   ('afforded', 1),
#   ('ahetuka', 1),
#   ('akkosa', 1),
#   ('alluding', 1),
#   ('ambattha', 1),
#   ('ambiguity', 1),
#   ('amenable', 1),
#   ('analysing', 1),
#   ('anamatagga', 1),
#   ('anantanaya', 1),
#   ('annihilationists', 1),
#   ('annoying', 1),
#   ('annual', 1),
#   ('apara', 1),
#   ('apprehends', 1),
#   ('approbation', 1),
#   ('aputtaka', 1),
#   ('arahattaphala', 1),
#   ('ardour', 1),
#   ('ariyapariyesana', 1),
#   ('arouses', 1),
#   ('asati', 1),
#   ('ascertaining', 1),
#   ('asibandhakaputta', 1),
#   ('asoka', 1),
#   ('aspirant', 1),
#   ('attends', 1),
#   ('attentiveness', 1),
#   ('augmenting', 1),
#   ('aura', 1),
#   ('badda', 1),
#   ('bandit', 1),
#   ('barkdyed', 1),
#   ('bdeabuddhanetnet', 1),
#   ('becloud', 1),
#   ('beclouded', 1),
#   ('begrudging', 1),
#   ('bemoans', 1),
#   ('bemused', 1),
#   ('bhallika', 1),
#   ('bhikkhunupassaya', 1),
#   ('biography', 1),
#   ('birthlinking', 1),
#   ('blurts', 1),
#   ('bodhivagga', 1),
#   ('bodylength', 1),
#   ('brahmacariya', 1),
#   ('brahmadatta', 1),
#   ('buddhaghosa', 1),
#   ('buddhavisayo', 1),
#   ('calmly', 1),
#   ('captor', 1),
#   ('carnage', 1),
#   ('catcher', 1),
#   ('causally', 1),
#   ('censurable', 1),
#   ('cetasikas', 1),
#   ('chairman', 1),
#   ('chan', 1),
#   ('characterise', 1),
#   ('classical', 1),
#   ('classifies', 1),
#   ('clutched', 1),
#   ('coax', 1),
#   ('colloquial', 1),
#   ('commentarial', 1),
#   ('composite', 1),
#   ('comprehensible', 1),
#   ('concentrationmeditation', 1),
#   ('conceptual', 1),
#   ('concise', 1),
#   ('concurred', 1),
#   ('condensed', 1),
#   ('conduciveness', 1),
#   ('conjuror', 1),
#   ('consoling', 1),
#   ('consultant', 1),
#   ('continuation', 1),
#   ('continuum', 1),
#   ('contrasted', 1),
#   ('convened', 1),
#   ('conversely', 1),
#   ('coordinated', 1),
#   ('cordial', 1),
#   ('cough', 1),
#   ('countered', 1),
#   ('countering', 1),
#   ('counterquestions', 1),
#   ('courtesan', 1),
#   ('crept', 1),
#   ('crippling', 1),
#   ('cudgel', 1),
#   ('dahara', 1),
#   ('dalhanemi', 1),
#   ('dasama', 1),
#   ('dassana', 1),
#   ('debators', 1),
#   ('decomposition', 1),
#   ('define', 1),
#   ('demonstrating', 1),
#   ('depict', 1),
#   ('deranged', 1),
#   ('derisively', 1),
#   ('devaputta', 1),
#   ('devata', 1),
#   ('dewdrop', 1),
#   ('dhammacakka', 1),
#   ('dhammahadaya', 1),
#   ('dhanet', 1),
#   ('dhura', 1),
#   ('discursive', 1),
#   ('disliking', 1),
#   ('disparage', 1),
#   ('disparaged', 1),
#   ('disparagement', 1),
#   ('dispassion', 1),
#   ('dispraise', 1),
#   ('disrepute', 1),
#   ('dissociating', 1),
#   ('domanassa', 1),
#   ('donating', 1),
#   ('donee', 1),
#   ('dualistic', 1),
#   ('dumbness', 1),
#   ('dustladen', 1),
#   ('dutifully', 1),
#   ('dutiya', 1),
#   ('dwindled', 1),
#   ('edifice', 1),
#   ('editor', 1),
#   ('editorinchief', 1),
#   ('eightynine', 1),
#   ('ekacca', 1),
#   ('eloquently', 1),
#   ('enervated', 1),
#   ('enquires', 1),
#   ('entertaining', 1),
#   ('episode', 1),
#   ('esa', 1),
#   ('etadagga', 1),
#   ('evading', 1),
#   ('evasion', 1),
#   ('exascetic', 1),
#   ('exonerating', 1),
#   ('exwife', 1),
#   ('facilitated', 1),
#   ('fallacy', 1),
#   ('fanning', 1),
#   ('fathomable', 1),
#   ('fathomless', 1),
#   ('february', 1),
#   ('fibrous', 1),
#   ('finely', 1),
#   ('fingersnap', 1),
#   ('fireworship', 1),
#   ('firstly', 1),
#   ('fluidity', 1),
#   ('footwear', 1),
#   ('fruitionmind', 1),
#   ('fullfledged', 1),
#   ('futility', 1),
#   ('gandhabba', 1),
#   ('gantha', 1),
#   ('geography', 1),
#   ('gottas', 1),
#   ('graecobactrian', 1),
#   ('halfmonth', 1),
#   ('handing', 1),
#   ('handy', 1),
#   ('harmfulness', 1),
#   ('harmlessly', 1),
#   ('helterskelter', 1),
#   ('heterodox', 1),
#   ('hetu', 1),
#   ('hinders', 1),
#   ('hla', 1),
#   ('homageworthy', 1),
#   ('htoon', 1),
#   ('htut', 1),
#   ('iiieight', 1),
#   ('illustrative', 1),
#   ('imassa', 1),
#   ('imbalance', 1),
#   ('immoderation', 1),
#   ('impermanency', 1),
#   ('imperturbability', 1),
#   ('implored', 1),
#   ('imponderable', 1),
#   ('impossibility', 1),
#   ('inbreath', 1),
#   ('incantation', 1),
#   ('incurring', 1),
#   ('indebtedness', 1),
#   ('indefatigable', 1),
#   ('indisciplined', 1),
#   ('indomitable', 1),
#   ('inflicting', 1),
#   ('infringement', 1),
#   ('insubstantial', 1),
#   ('interdependence', 1),
#   ('interspersed', 1),
#   ('intrinsically', 1),
#   ('invective', 1),
#   ('inversion', 1),
#   ('irascible', 1),
#   ('irksome', 1),
#   ('irritable', 1),
#   ('isipatana', 1),
#   ('issariya', 1),
#   ('ivi', 1),
#   ('ivseven', 1),
#   ('jeopardising', 1),
#   ('jubilant', 1),
#   ('kakusandha', 1),
#   ('kalanda', 1),
#   ('kammic', 1),
#   ('kassapas', 1),
#   ('kathina', 1),
#   ('kesamutta', 1),
#   ('kesamutti', 1),
#   ('khandhakas', 1),
#   ('khema', 1),
#   ('khuddhaka', 1),
#   ('kilesa', 1),
#   ('kith', 1),
#   ('koliya', 1),
#   ('kosalas', 1),
#   ('kyaw', 1),
#   ('landholder', 1),
#   ('landowner', 1),
#   ('lastly', 1),
#   ('layfolks', 1),
#   ('laywomen', 1),
#   ('leafstalk', 1),
#   ('liability', 1),
#   ('liberality', 1),
#   ('lifeprocess', 1),
#   ('likening', 1),
#   ('lingers', 1),
#   ('lkaka', 1),
#   ('llb', 1),
#   ('lokuttara', 1),
#   ('luckier', 1),
#   ('mahaggata', 1),
#   ('makkhali', 1),
#   ('malla', 1),
#   ('malleable', 1),
#   ('markettown', 1),
#   ('materiality', 1),
#   ('meagre', 1),
#   ('meanness', 1),
#   ('medicinal', 1),
#   ('mediocre', 1),
#   ('memorization', 1),
#   ('menaced', 1),
#   ('menfolk', 1),
#   ('meshed', 1),
#   ('methodological', 1),
#   ('metrical', 1),
#   ('metteyya', 1),
#   ('midriver', 1),
#   ('mindfully', 1),
#   ('mindintoxicating', 1),
#   ('mindobject', 1),
#   ('misconstruction', 1),
#   ('misconstrued', 1),
#   ('moggaliputta', 1),
#   ('mohana', 1),
#   ('motivating', 1),
#   ('mra', 1),
#   ('msc', 1),
#   ('multimillionaire', 1),
#   ('mya', 1),
#   ('nagaravinda', 1),
#   ('nahetu', 1),
#   ('nakulapitu', 1),
#   ('nandaka', 1),
#   ('ngwe', 1),
#   ('nicca', 1),
#   ('nigrodha', 1),
#   ('nirujjhati', 1),
#   ('nobleness', 1),
#   ('noform', 1),
#   ('nonarising', 1),
#   ('noncarnal', 1),
#   ('noncausality', 1),
#   ('nondelusion', 1),
#   ('noneternity', 1),
#   ('nongiver', 1),
#   ('nongreed', 1),
#   ('nonhatred', 1),
#   ('nonhuman', 1),
#   ('nutshell', 1),
#   ('nyun', 1),
#   ('obliquely', 1),
#   ('obscene', 1),
#   ('occasionally', 1),
#   ('occurring', 1),
#   ('onerous', 1),
#   ('outbreath', 1),
#   ('outlook', 1),
#   ('pakkha', 1),
#   ('pakudha', 1),
#   ('paralytic', 1),
#   ('paramount', 1),
#   ('pariyatti', 1),
#   ('patisandhi', 1),
#   ('payatta', 1),
#   ('permuted', 1),
#   ('pessa', 1),
#   ('petakopadesa', 1),
#   ('petavatthu', 1),
#   ('phassa', 1),
#   ('physiognomic', 1),
#   ('pilotika', 1),
#   ('pithy', 1),
#   ('pleasurableness', 1),
#   ('pliant', 1),
#   ('plod', 1),
#   ('plodded', 1),
#   ('predicament', 1),
#   ('presaged', 1),
#   ('progressed', 1),
#   ('prohibitory', 1),
#   ('propounded', 1),
#   ('protruding', 1),
#   ('pubba', 1),
#   ('pucchaka', 1),
#   ('puggalas', 1),
#   ('puppha', 1),
#   ('puthujjana', 1),
#   ('quay', 1),
#   ('reappear', 1),
#   ('recalcitrant', 1),
#   ('recalling', 1),
#   ('reeking', 1),
#   ('refutes', 1),
#   ('rehabilitated', 1),
#   ('reinstate', 1),
#   ('relinquishing', 1),
#   ('remedied', 1),
#   ('remonstrated', 1),
#   ('remorseful', 1),
#   ('repelling', 1),
#   ('resembled', 1),
#   ('respiration', 1),
#   ('retaliating', 1),
#   ('retold', 1),
#   ('returner', 1),
#   ('revata', 1),
#   ('reviler', 1),
#   ('rickety', 1),
#   ('roofless', 1),
#   ('rousing', 1),
#   ('salutory', 1),
#   ('samana', 1),
#   ('samanta', 1),
#   ('samatha', 1),
#   ('satisfactorily', 1),
#   ('sawing', 1),
#   ('sayadaw', 1),
#   ('scenery', 1),
#   ('schismatic', 1),
#   ('scruple', 1),
#   ('scrutinize', 1),
#   ('scrutinized', 1),
#   ('secretariat', 1),
#   ('sectleaders', 1),
#   ('selects', 1),
#   ('selfconfidence', 1),
#   ('selfdevelopment', 1),
#   ('selfexamination', 1),
#   ('selfpossessed', 1),
#   ('selfrestraints', 1),
#   ('seniority', 1),
#   ('seniya', 1),
#   ('sensecontrol', 1),
#   ('sensedesire', 1),
#   ('sensedesires', 1),
#   ('sensefaculties', 1),
#   ('sensepleasures', 1),
#   ('shielded', 1),
#   ('shwe', 1),
#   ('singly', 1),
#   ('sneeze', 1),
#   ('solaced', 1),
#   ('solidity', 1),
#   ('soliloquy', 1),
#   ('somanassa', 1),
#   ('specialized', 1),
#   ('spontaneous', 1),
#   ('spurning', 1),
#   ('squeezing', 1),
#   ('starvation', 1),
#   ('stimulating', 1),
#   ('stranded', 1),
#   ('stupa', 1),
#   ('stupidity', 1),
#   ('subcommentary', 1),
#   ('subgroup', 1),
#   ('subhadda', 1),
#   ('succumbed', 1),
#   ('sudinna', 1),
#   ('sulkiness', 1),
#   ('sunakkhattas', 1),
#   ('suppiya', 1),
#   ('supplementing', 1),
#   ('supplicated', 1),
#   ('survival', 1),
#   ('suttantika', 1),
#   ('synthesis', 1),
#   ('systematization', 1),
#   ('tabulated', 1),
#   ('taint', 1),
#   ('talented', 1),
#   ('tapussa', 1),
#   ('thein', 1),
#   ('threadbare', 1),
#   ('thullaccaya', 1),
#   ('tipitaka', 1),
#   ('touring', 1),
#   ('trilogy', 1),
#   ('twowheeler', 1),
#   ('uccheda', 1),
#   ('udayabbaya', 1),
#   ('uggahamana', 1),
#   ('unaccompanied', 1),
#   ('unattained', 1),
#   ('unconditioned', 1),
#   ('unconfused', 1),
#   ('uncultivated', 1),
#   ('undermines', 1),
#   ('undesirability', 1),
#   ('unenduring', 1),
#   ('unexcited', 1),
#   ('unfriendly', 1),
#   ('unimpaired', 1),
#   ('unloved', 1),
#   ('unmindfully', 1),
#   ('unperceiving', 1),
#   ('unpleasantness', 1),
#   ('unreliable', 1),
#   ('unremittingly', 1),
#   ('unrepentant', 1),
#   ('unshakeable', 1),
#   ('untarnished', 1),
#   ('untiring', 1),
#   ('untold', 1),
#   ('untoward', 1),
#   ('untrustworthy', 1),
#   ('uppajjati', 1),
#   ('upturned', 1),
#   ('uttara', 1),
#   ('uttaras', 1),
#   ('vacana', 1),
#   ('vagary', 1),
#   ('vasala', 1),
#   ('vassas', 1),
#   ('venerables', 1),
#   ('venturing', 1),
#   ('vicechancellor', 1),
#   ('vicissitude', 1),
#   ('viixii', 1),
#   ('vimutti', 1),
#   ('vinayadharas', 1),
#   ('voli', 1),
#   ('wellqualified', 1),
#   ('wellreasoned', 1),
#   ('wellversed', 1),
#   ('womenfolk', 1),
#   ('wrathfulness', 1),
#   ('wwwbuddhanetnet', 1),
#   ('yebhuyyasika', 1),
#   ('yonaka', 1),
#   ('yuganaddha', 1)],
#  'Gita': [('bhaktivedanta', 1063),
#   ('intl', 1026),
#   ('tel', 398),
#   ('supersoul', 165),
#   ('fax', 140),
#   ('fruitive', 129),
#   ('opulence', 79),
#   ('demoniac', 70),
#   ('rd', 69),
#   ('bhaktiyoga', 68),
#   ('tu', 66),
#   ('bona', 65),
#   ('fide', 65),
#   ('transcendentalist', 59),
#   ('confidential', 52),
#   ('constitutional', 52),
#   ('mae', 52),
#   ('socalled', 52),
#   ('caitanya', 51),
#   ('api', 48),
#   ('symptom', 47),
#   ('yo', 47),
#   ('aham', 43),
#   ('disciplic', 42),
#   ('tae', 39),
#   ('impersonalists', 38),
#   ('govinda', 36),
#   ('restaurant', 36),
#   ('brahmajyoti', 34),
#   ('paaqar', 34),
#   ('proprietor', 34),
#   ('caiva', 33),
#   ('kmar', 33),
#   ('ovac', 33),
#   ('duryodhana', 32),
#   ('materially', 32),
#   ('plenary', 31),
#   ('ucyate', 31),
#   ('mightyarmed', 30),
#   ('tasya', 30),
#   ('goloka', 29),
#   ('impersonalist', 29),
#   ('individuality', 29),
#   ('perfectional', 29),
#   ('regulative', 29),
#   ('factually', 28),
#   ('karmayoga', 28),
#   ('wv', 28),
#   ('atheistic', 27),
#   ('combination', 27),
#   ('inconceivable', 27),
#   ('kaunteya', 27),
#   ('tau', 27),
#   ('unmanifested', 27),
#   ('fragmental', 25),
#   ('iskcon', 25),
#   ('kaentaeya', 25),
#   ('sungod', 25),
#   ('transcendentally', 25),
#   ('servitor', 24),
#   ('buddhiyoga', 23),
#   ('etad', 23),
#   ('transcendence', 23),
#   ('viddhi', 23),
#   ('aarta', 22),
#   ('ajaurna', 22),
#   ('bhavati', 21),
#   ('rural', 21),
#   ('cev', 20),
#   ('foodstuff', 20),
#   ('localized', 20),
#   ('military', 20),
#   ('unalloyed', 20),
#   ('worshipable', 20),
#   ('dehe', 19),
#   ('govindas', 19),
#   ('mentality', 19),
#   ('miscreant', 19),
#   ('propensity', 19),
#   ('yaae', 19),
#   ('atheist', 18),
#   ('ave', 18),
#   ('conviction', 18),
#   ('mayi', 18),
#   ('sarvam', 18),
#   ('fourhanded', 17),
#   ('scientist', 17),
#   ('avyayam', 16),
#   ('dist', 16),
#   ('eatable', 16),
#   ('sarvasya', 16),
#   ('sarve', 16),
#   ('yasya', 16),
#   ('atha', 15),
#   ('mysticism', 15),
#   ('nescience', 15),
#   ('proprietorship', 15),
#   ('taqaa', 15),
#   ('tata', 15),
#   ('vetti', 15),
#   ('vidyate', 15),
#   ('autaaina', 14),
#   ('eko', 14),
#   ('endeavoring', 14),
#   ('exhibited', 14),
#   ('fiji', 14),
#   ('mahabahae', 14),
#   ('parma', 14),
#   ('tva', 14),
#   ('yaaegaq', 14),
#   ('bhaktir', 13),
#   ('brahmaloka', 13),
#   ('eightfold', 13),
#   ('inaction', 13),
#   ('inauspicious', 13),
#   ('kmaaria', 13),
#   ('maiya', 13),
#   ('occupational', 13),
#   ('personalist', 13),
#   ('twohanded', 13),
#   ('yena', 13),
#   ('banyan', 12),
#   ('buddhir', 12),
#   ('harer', 12),
#   ('nondevotees', 12),
#   ('partial', 12),
#   ('prabhupada', 12),
#   ('rjuna', 12),
#   ('rua', 12),
#   ('tatra', 12),
#   ('unauthorized', 12),
#   ('wita', 12),
#   ('yac', 12),
#   ('yada', 12),
#   ('yaqaa', 12),
#   ('av', 11),
#   ('gatim', 11),
#   ('indirectly', 11),
#   ('knowable', 11),
#   ('nonmoving', 11),
#   ('pakita', 11),
#   ('practically', 11),
#   ('punar', 11),
#   ('regardless', 11),
#   ('smi', 11),
#   ('tataae', 11),
#   ('vasudeva', 11),
#   ('veita', 11),
#   ('yaainta', 11),
#   ('abovementioned', 10),
#   ('accidental', 10),
#   ('avita', 10),
#   ('baladeva', 10),
#   ('electricity', 10),
#   ('factual', 10),
#   ('inatya', 10),
#   ('kza', 10),
#   ('mahattattva', 10),
#   ('mata', 10),
#   ('parantapa', 10),
#   ('parntapa', 10),
#   ('paxyaita', 10),
#   ('saver', 10),
#   ('speculator', 10),
#   ('yogam', 10),
#   ('autva', 9),
#   ('auya', 9),
#   ('bhava', 9),
#   ('calle', 9),
#   ('degradation', 9),
#   ('factory', 9),
#   ('fl', 9),
#   ('gaitama', 9),
#   ('guaranteed', 9),
#   ('loke', 9),
#   ('mayy', 9),
#   ('pauna', 9),
#   ('selfcontrolled', 9),
#   ('tava', 9),
#   ('whimsically', 9),
#   ('yaaega', 9),
#   ('aquatic', 8),
#   ('bangladesh', 8),
#   ('boyhood', 8),
#   ('byproduct', 8),
#   ('chastiser', 8),
#   ('conchshells', 8),
#   ('dictionary', 8),
#   ('discharging', 8),
#   ('drupada', 8),
#   ('ete', 8),
#   ('eti', 8),
#   ('evam', 8),
#   ('fallible', 8),
#   ('govindam', 8),
#   ('ipaya', 8),
#   ('kqa', 8),
#   ('madhu', 8),
#   ('madhya', 8),
#   ('nondevotee', 8),
#   ('ocyatae', 8),
#   ('respectable', 8),
#   ('satv', 8),
#   ('savrsya', 8),
#   ('savrxa', 8),
#   ('solve', 8),
#   ('svayam', 8),
#   ('tathaiva', 8),
#   ('technically', 8),
#   ('unnecessarily', 8),
#   ('utilize', 8),
#   ('administrator', 7),
#   ('artazra', 7),
#   ('asura', 7),
#   ('befitting', 7),
#   ('concoction', 7),
#   ('daita', 7),
#   ('dovetailed', 7),
#   ('easiest', 7),
#   ('falldown', 7),
#   ('firstclass', 7),
#   ('infection', 7),
#   ('introspective', 7),
#   ('irreligion', 7),
#   ('ivxainta', 7),
#   ('kalpate', 7),
#   ('labhate', 7),
#   ('marg', 7),
#   ('marginal', 7),
#   ('naev', 7),
#   ('naiva', 7),
#   ('nz', 7),
#   ('opp', 7),
#   ('palatable', 7),
#   ('paxyaaima', 7),
#   ('prague', 7),
#   ('prapadyante', 7),
#   ('pseudo', 7),
#   ('qualitatively', 7),
#   ('quitting', 7),
#   ('reciprocation', 7),
#   ('sarvatra', 7),
#   ('savrautaanaa', 7),
#   ('sinless', 7),
#   ('smaran', 7),
#   ('srila', 7),
#   ('sukham', 7),
#   ('suva', 7),
#   ('taeza', 7),
#   ('tena', 7),
#   ('uttamam', 7),
#   ('variegatedness', 7),
#   ('vasus', 7),
#   ('vegetarian', 7),
#   ('wb', 7),
#   ('yaaita', 7),
#   ('yaena', 7),
#   ('advancing', 6),
#   ('ante', 6),
#   ('aqa', 6),
#   ('arhasi', 6),
#   ('aristocratic', 6),
#   ('ascertain', 6),
#   ('autaezu', 6),
#   ('brahmacarya', 6),
#   ('california', 6),
#   ('canto', 6),
#   ('chemical', 6),
#   ('divyam', 6),
#   ('dominate', 6),
#   ('dublin', 6),
#   ('equipoised', 6),
#   ('glaring', 6),
#   ('hospital', 6),
#   ('illusioned', 6),
#   ('intimately', 6),
#   ('jatva', 6),
#   ('jeya', 6),
#   ('karnataka', 6),
#   ('ktaar', 6),
#   ('ktva', 6),
#   ('manaae', 6),
#   ('manufactured', 6),
#   ('manye', 6),
#   ('mayapur', 6),
#   ('nityo', 6),
#   ('nivartante', 6),
#   ('paapya', 6),
#   ('parabrahman', 6),
#   ('practitioner', 6),
#   ('production', 6),
#   ('purificatory', 6),
#   ('saaitvk', 6),
#   ('sarvair', 6),
#   ('satata', 6),
#   ('savaria', 6),
#   ('savr', 6),
#   ('savra', 6),
#   ('steadiness', 6),
#   ('subduer', 6),
#   ('theoretically', 6),
#   ('tolerates', 6),
#   ('ubhayor', 6),
#   ('vidur', 6),
#   ('yaid', 6),
#   ('yan', 6),
#   ('yas', 6),
#   ('yato', 6),
#   ('yogo', 6),
#   ('yukta', 6),
#   ('advaita', 5),
#   ('ananta', 5),
#   ('anye', 5),
#   ('apartado', 5),
#   ('asita', 5),
#   ('aspire', 5),
#   ('baffled', 5),
#   ('bata', 5),
#   ('bhajate', 5),
#   ('bhavanti', 5),
#   ('buenos', 5),
#   ('centro', 5),
#   ('cochabamba', 5),
#   ('croatia', 5),
#   ('czech', 5),
#   ('del', 5),
#   ('dev', 5),
#   ('devala', 5),
#   ('dham', 5),
#   ('disc', 5),
#   ('dormant', 5),
#   ('dual', 5),
#   ('empiric', 5),
#   ('etat', 5),
#   ('falldowns', 5),
#   ('flaw', 5),
#   ('govardhana', 5),
#   ('grandsire', 5),
#   ('iaivda', 5),
#   ('impregnates', 5),
#   ('incarnates', 5),
#   ('incomplete', 5),
#   ('independently', 5),
#   ('indirect', 5),
#   ('isqata', 5),
#   ('ivdu', 5),
#   ('jaayatae', 5),
#   ('jagannath', 5),
#   ('jagata', 5),
#   ('juhvati', 5),
#   ('kalevaram', 5),
#   ('kaya', 5),
#   ('kexav', 5),
#   ('kmaria', 5),
#   ('kurvan', 5),
#   ('kuto', 5),
#   ('laeke', 5),
#   ('loko', 5),
#   ('los', 5),
#   ('madhye', 5),
#   ('matpara', 5),
#   ('misuse', 5),
#   ('moonshine', 5),
#   ('mukti', 5),
#   ('nirukti', 5),
#   ('nondifferent', 5),
#   ('nonpermanent', 5),
#   ('nonviolent', 5),
#   ('opulent', 5),
#   ('padma', 5),
#   ('paja', 5),
#   ('pavitram', 5),
#   ('payaurpaasatae', 5),
#   ('phalam', 5),
#   ('qld', 5),
#   ('rajasa', 5),
#   ('residential', 5),
#   ('sannyasya', 5),
#   ('saverzu', 5),
#   ('savrautaezu', 5),
#   ('savrimad', 5),
#   ('saxaya', 5),
#   ('scion', 5),
#   ('selfsatisfaction', 5),
#   ('sma', 5),
#   ('smashed', 5),
#   ('str', 5),
#   ('superficially', 5),
#   ('surabhi', 5),
#   ('sve', 5),
#   ('sydney', 5),
#   ('tac', 5),
#   ('tada', 5),
#   ('taezu', 5),
#   ('tair', 5),
#   ('taman', 5),
#   ('tatvta', 5),
#   ('tn', 5),
#   ('transmigrating', 5),
#   ('unfavorable', 5),
#   ('utilized', 5),
#   ('vartate', 5),
#   ('vic', 5),
#   ('villa', 5),
#   ('vraja', 5),
#   ('yaaeigana', 5),
#   ('yaeza', 5),
#   ('yajantae', 5),
#   ('yajante', 5),
#   ('yajjatva', 5),
#   ('acintya', 4),
#   ('affectionate', 4),
#   ('ajam', 4),
#   ('alldevouring', 4),
#   ('apparently', 4),
#   ('assam', 4),
#   ('beginningless', 4),
#   ('bhajante', 4),
#   ('bhajanti', 4),
#   ('bhajati', 4),
#   ('bhaktiyogena', 4),
#   ('bhaved', 4),
#   ('blvd', 4),
#   ('boon', 4),
#   ('budapest', 4),
#   ('cafe', 4),
#   ('cc', 4),
#   ('cet', 4),
#   ('col', 4),
#   ('contradictory', 4),
#   ('cooperation', 4),
#   ('curbed', 4),
#   ('curitiba', 4),
#   ('degrade', 4),
#   ('degraded', 4),
#   ('demerara', 4),
#   ('deve', 4),
#   ('dharmasya', 4),
#   ('dogeater', 4),
#   ('faulty', 4),
#   ('flma', 4),
#   ('florida', 4),
#   ('fortunately', 4),
#   ('gacchanty', 4),
#   ('gandharvas', 4),
#   ('generating', 4),
#   ('genitals', 4),
#   ('gratificatory', 4),
#   ('grossly', 4),
#   ('gurabo', 4),
#   ('guyana', 4),
#   ('ilpyatae', 4),
#   ('impersonalism', 4),
#   ('inayata', 4),
#   ('jaipur', 4),
#   ('janmani', 4),
#   ('kaliyuga', 4),
#   ('kandarpa', 4),
#   ('karoti', 4),
#   ('kartum', 4),
#   ('kenya', 4),
#   ('kmaraa', 4),
#   ('kriyate', 4),
#   ('kurute', 4),
#   ('latae', 4),
#   ('lipyate', 4),
#   ('lokam', 4),
#   ('maamaev', 4),
#   ('madausaudna', 4),
#   ('madya', 4),
#   ('mahad', 4),
#   ('mahato', 4),
#   ('manasaa', 4),
#   ('manufacturing', 4),
#   ('manyatae', 4),
#   ('manyate', 4),
#   ('matam', 4),
#   ('mauritius', 4),
#   ('mercantile', 4),
#   ('missionary', 4),
#   ('monist', 4),
#   ('monists', 4),
#   ('mukunda', 4),
#   ('naae', 4),
#   ('naena', 4),
#   ('nivartate', 4),
#   ('nivasaty', 4),
#   ('nonregulated', 4),
#   ('opaasatae', 4),
#   ('parityajya', 4),
#   ('parmaa', 4),
#   ('partandparcel', 4),
#   ('pavita', 4),
#   ('pennsylvania', 4),
#   ('perak', 4),
#   ('phalanx', 4),
#   ('phalgu', 4),
#   ('predicted', 4),
#   ('predominant', 4),
#   ('program', 4),
#   ('rajya', 4),
#   ('recommendation', 4),
#   ('religiosity', 4),
#   ('sada', 4),
#   ('salvador', 4),
#   ('sannyaasa', 4),
#   ('sarva', 4),
#   ('savrautaaina', 4),
#   ('savrta', 4),
#   ('sayamya', 4),
#   ('senayor', 4),
#   ('somarasa', 4),
#   ('sp', 4),
#   ('staircase', 4),
#   ('sthito', 4),
#   ('strategic', 4),
#   ('stu', 4),
#   ('successfully', 4),
#   ('summarize', 4),
#   ('superintendence', 4),
#   ('supermost', 4),
#   ('superself', 4),
#   ('svaavjama', 4),
#   ('switzerland', 4),
#   ('tapasya', 4),
#   ('tatam', 4),
#   ('thirdclass', 4),
#   ('transformation', 4),
#   ('trinidad', 4),
#   ('uncommon', 4),
#   ('undergoing', 4),
#   ('unscrupulous', 4),
#   ('upaiti', 4),
#   ('viddhy', 4),
#   ('vrindavan', 4),
#   ('wd', 4),
#   ('windyaaia', 4),
#   ('xakya', 4),
#   ('yasmin', 4),
#   ('yuge', 4),
#   ('yukto', 4),
#   ('aasaur', 3),
#   ('actuality', 3),
#   ('acyuta', 3),
#   ('adhigacchati', 3),
#   ('adopts', 3),
#   ('advayam', 3),
#   ('aea', 3),
#   ('agnihotra', 3),
#   ('agnir', 3),
#   ('agnostic', 3),
#   ('agre', 3),
#   ('ahmedabad', 3),
#   ('aipa', 3),
#   ('airport', 3),
#   ('aja', 3),
#   ('ajantae', 3),
#   ('ajo', 3),
#   ('akarma', 3),
#   ('alaminos', 3),
#   ('amaa', 3),
#   ('amaq', 3),
#   ('angeles', 3),
#   ('anityam', 3),
#   ('antavanta', 3),
#   ('antiseptic', 3),
#   ('anusmara', 3),
#   ('anyae', 3),
#   ('anyena', 3),
#   ('apakvo', 3),
#   ('apare', 3),
#   ('arpitamanobuddhir', 3),
#   ('assuming', 3),
#   ('atho', 3),
#   ('attainable', 3),
#   ('auckland', 3),
#   ('avajaurna', 3),
#   ('avyakta', 3),
#   ('avyakto', 3),
#   ('awkward', 3),
#   ('aya', 3),
#   ('bahavo', 3),
#   ('bangalore', 3),
#   ('beginner', 3),
#   ('bhagavan', 3),
#   ('bhagavaty', 3),
#   ('bhajann', 3),
#   ('bhavato', 3),
#   ('bhavet', 3),
#   ('brahmanrealized', 3),
#   ('brisbane', 3),
#   ('cah', 3),
#   ('caitanyas', 3),
#   ('cajaurna', 3),
#   ('candra', 3),
#   ('capare', 3),
#   ('cessnock', 3),
#   ('cetasaa', 3),
#   ('ceti', 3),
#   ('clearing', 3),
#   ('colombia', 3),
#   ('commentation', 3),
#   ('congenial', 3),
#   ('conjunction', 3),
#   ('copenhagen', 3),
#   ('counterattack', 3),
#   ('coventry', 3),
#   ('daea', 3),
#   ('daityas', 3),
#   ('damarsya', 3),
#   ('damya', 3),
#   ('dehinam', 3),
#   ('dehq', 3),
#   ('delhi', 3),
#   ('destructible', 3),
#   ('deteriorate', 3),
#   ('deteriorates', 3),
#   ('devexa', 3),
#   ('devo', 3),
#   ('devq', 3),
#   ('dhama', 3),
#   ('differentiation', 3),
#   ('digesting', 3),
#   ('digestion', 3),
#   ('diplomacy', 3),
#   ('disturbs', 3),
#   ('duryodhanas', 3),
#   ('ecuador', 3),
#   ('egoism', 3),
#   ('ekam', 3),
#   ('ekaterinburg', 3),
#   ('ephemeral', 3),
#   ('etair', 3),
#   ('evaiti', 3),
#   ('evaluation', 3),
#   ('evolutionary', 3),
#   ('experimental', 3),
#   ('extraneous', 3),
#   ('faltering', 3),
#   ('faultfinding', 3),
#   ('flickering', 3),
#   ('flowery', 3),
#   ('gacchanti', 3),
#   ('gacinta', 3),
#   ('gatir', 3),
#   ('gauaa', 3),
#   ('gauakexa', 3),
#   ('gaura', 3),
#   ('georgia', 3),
#   ('ghostly', 3),
#   ('glorification', 3),
#   ('gratify', 3),
#   ('greatgrandfather', 3),
#   ('grossest', 3),
#   ('guadalajara', 3),
#   ('guesthouse', 3),
#   ('gymnastic', 3),
#   ('hanker', 3),
#   ('hanti', 3),
#   ('hanyate', 3),
#   ('herculean', 3),
#   ('hinta', 3),
#   ('htva', 3),
#   ('illegal', 3),
#   ('imagining', 3),
#   ('impractical', 3),
#   ('impregnated', 3),
#   ('inabdyatae', 3),
#   ('inavtarntae', 3),
#   ('inconvenience', 3),
#   ('incorrect', 3),
#   ('indie', 3),
#   ('indolence', 3),
#   ('indore', 3),
#   ('indraloka', 3),
#   ('influential', 3),
#   ('irreligious', 3),
#   ('ivhaya', 3),
#   ('ivixazyatae', 3),
#   ('ivndita', 3),
#   ('jaatau', 3),
#   ('jakarta', 3),
#   ('janaadrna', 3),
#   ('janaq', 3),
#   ('jayadratha', 3),
#   ('jose', 3),
#   ('kampala', 3),
#   ('karmasu', 3),
#   ('kathyate', 3),
#   ('kaxaita', 3),
#   ('kecid', 3),
#   ('kecskemet', 3),
#   ('kena', 3),
#   ('klpatae', 3),
#   ('kmaraae', 3),
#   ('kmarsau', 3),
#   ('kraeita', 3),
#   ('krsna', 3),
#   ('ktau', 3),
#   ('kumbhakayoga', 3),
#   ('kurunandana', 3),
#   ('kuvera', 3),
#   ('kva', 3),
#   ('kvacit', 3),
#   ('labhante', 3),
#   ('laguna', 3),
#   ('lantae', 3),
#   ('licking', 3),
#   ('lima', 3),
#   ('lokasya', 3),
#   ('lorong', 3),
#   ('madbhakto', 3),
#   ('magnanimity', 3),
#   ('mahatmana', 3),
#   ('manyasae', 3),
#   ('manyase', 3),
#   ('manyhooded', 3),
#   ('matama', 3),
#   ('mathura', 3),
#   ('matpar', 3),
#   ('matva', 3),
#   ('maua', 3),
#   ('meateating', 3),
#   ('melbourne', 3),
#   ('miguel', 3),
#   ('mp', 3),
#   ('mriyate', 3),
#   ('munir', 3),
#   ('naaya', 3),
#   ('namaskuru', 3),
#   ('negeri', 3),
#   ('neutrality', 3),
#   ('nibadhnanti', 3),
#   ('nibadhyate', 3),
#   ('nibodha', 3),
#   ('nirmamo', 3),
#   ('nityam', 3),
#   ('niyama', 3),
#   ('nondoer', 3),
#   ('nonsensical', 3),
#   ('novemberdecember', 3),
#   ('nueva', 3),
#   ('nyo', 3),
#   ('opposing', 3),
#   ('outlet', 3),
#   ('paaae', 3),
#   ('paitaa', 3),
#   ('pajaa', 3),
#   ('palya', 3),
#   ('pasaqd', 3),
#   ('patet', 3),
#   ('patir', 3),
#   ('paunajarnma', 3),
#   ('paxya', 3),
#   ('paxyainta', 3),
#   ('personalists', 3),
#   ('phantasmagoria', 3),
#   ('philanthropist', 3),
#   ('philippine', 3),
#   ('plaza', 3),
#   ('poland', 3),
#   ('prabhu', 3),
#   ('predominantly', 3),
#   ('predominator', 3),
#   ('priyo', 3),
#   ('proktam', 3),
#   ('prowess', 3),
#   ('puerto', 3),
#   ('punas', 3),
#   ('quarreling', 3),
#   ('rajasaq', 3),
#   ('recreation', 3),
#   ('remuneration', 3),
#   ('replica', 3),
#   ('restaurante', 3),
#   ('restrict', 3),
#   ('rico', 3),
#   ('saaitvki', 3),
#   ('sadaiva', 3),
#   ('samadusau', 3),
#   ('samudram', 3),
#   ('samyag', 3),
#   ('sarge', 3),
#   ('sarvato', 3),
#   ('sasmatya', 3),
#   ('satyam', 3),
#   ('savar', 3),
#   ('savrkmaaria', 3),
#   ('sector', 3),
#   ('seedgiving', 3),
#   ('selfilluminated', 3),
#   ('selfknowledge', 3),
#   ('selfluminous', 3),
#   ('sembilan', 3),
#   ('sentimentalist', 3),
#   ('sevonmukhe', 3),
#   ('siddhaye', 3),
#   ('siddhim', 3),
#   ('slightly', 3),
#   ('smatama', 3),
#   ('sofia', 3),
#   ('somadatta', 3),
#   ('sphuraty', 3),
#   ('spiritualist', 3),
#   ('spiritualized', 3),
#   ('sqaana', 3),
#   ('substantiate', 3),
#   ('sufferer', 3),
#   ('supervision', 3),
#   ('svena', 3),
#   ('sya', 3),
#   ('taamasaq', 3),
#   ('taeipa', 3),
#   ('taiping', 3),
#   ('tanum', 3),
#   ('taqaev', 3),
#   ('tasyaah', 3),
#   ('tatama', 3),
#   ('tattvavidas', 3),
#   ('tattvavit', 3),
#   ('tejas', 3),
#   ('tejo', 3),
#   ('teluk', 3),
#   ('tenaiva', 3),
#   ('tenthousandth', 3),
#   ('terrific', 3),
#   ('texas', 3),
#   ('tinge', 3),
#   ('tobago', 3),
#   ('toyam', 3),
#   ('tract', 3),
#   ('transmigrate', 3),
#   ('tribhir', 3),
#   ('twoarmed', 3),
#   ('tyajaty', 3),
#   ('tyajet', 3),
#   ('ubhe', 3),
#   ('ul', 3),
#   ('uta', 3),
#   ('utility', 3),
#   ('vaipa', 3),
#   ('vartanta', 3),
#   ('vc', 3),
#   ('vibhum', 3),
#   ('vikarma', 3),
#   ('vilokayanti', 3),
#   ('vindati', 3),
#   ('vividhaiva', 3),
#   ('vtarnta', 3),
#   ('vtartae', 3),
#   ('vyaaima', 3),
#   ('washington', 3),
#   ('whimsical', 3),
#   ('womanhood', 3),
#   ('wz', 3),
#   ('xaaec', 3),
#   ('xaaeictaumahrisa', 3),
#   ('xama', 3),
#   ('xara', 3),
#   ('xarqre', 3),
#   ('yaaegaae', 3),
#   ('yaaegaena', 3),
#   ('yatanto', 3),
#   ('yatau', 3),
#   ('yogayukto', 3),
#   ('yogena', 3),
#   ('yonir', 3),
#   ('yuddhe', 3),
#   ('yudhyasva', 3),
#   ('yujyate', 3),
#   ('aaegaa', 2),
#   ('aahara', 2),
#   ('aasaqta', 2),
#   ('aava', 2),
#   ('aavae', 2),
#   ('aavmajaanantaae', 2),
#   ('abhaktasya', 2),
#   ('abhayam', 2),
#   ('abhyarcya', 2),
#   ('abruptly', 2),
#   ('academically', 2),
#   ('accra', 2),
#   ('acyutam', 2),
#   ('adhidaiva', 2),
#   ('adhidaivata', 2),
#   ('adho', 2),
#   ('adurlabham', 2),
#   ('advaitam', 2),
#   ('advising', 2),
#   ('aeaj', 2),
#   ('agitating', 2),
#   ('aidaauta', 2),
#   ('aihsaa', 2),
#   ('aivtaa', 2),
#   ('alachua', 2),
#   ('alberta', 2),
#   ('allattractive', 2),
#   ('allgood', 2),
#   ('almaty', 2),
#   ('anagha', 2),
#   ('anantam', 2),
#   ('anantavijaya', 2),
#   ('aniruddha', 2),
#   ('annamaya', 2),
#   ('antonio', 2),
#   ('anyat', 2),
#   ('apaapya', 2),
#   ('apareyam', 2),
#   ('aprameyam', 2),
#   ('aqava', 2),
#   ('arcanum', 2),
#   ('arhasy', 2),
#   ('arouca', 2),
#   ('asaxaya', 2),
#   ('asito', 2),
#   ('aspires', 2),
#   ('ato', 2),
#   ('aural', 2),
#   ('auspiciousness', 2),
#   ('australia', 2),
# ...
#   ('chapiter', 25),
#   ('immolated', 25),
#   ('ninive', 25),
#   ('adonias', 24),
#   ('booz', 24),
#   ('ephi', 24),
#   ('gerson', 24),
#   ('haircloth', 24),
#   ('joachaz', 24),
#   ('maacha', 24),
#   ('mathathias', 24),
#   ('manfully', 23),
#   ('semeias', 23),
#   ('shewing', 23),
#   ('achis', 22),
#   ('assuerus', 22),
#   ('bacchides', 22),
#   ('cades', 22),
#   ('lachis', 22),
#   ('lia', 22),
#   ('maspha', 22),
#   ('onias', 22),
#   ('ptolemee', 22),
#   ('publican', 22),
#   ('raguel', 22),
#   ('sanctification', 22),
#   ('thamar', 22),
#   ('accaron', 21),
#   ('adarezer', 21),
#   ('ananias', 21),
#   ('baptism', 21),
#   ('elcana', 21),
#   ('gomorrha', 21),
#   ('hevite', 21),
#   ('jezabel', 21),
#   ('masphath', 21),
#   ('mosollam', 21),
#   ('nephthali', 21),
#   ('phares', 21),
#   ('rebecca', 21),
#   ('solicitous', 21),
#   ('thc', 21),
#   ('achitophel', 20),
#   ('ahicam', 20),
#   ('chanaanites', 20),
#   ('nathanael', 20),
#   ('tryphon', 20),
#   ('cariathiarim', 19),
#   ('foretold', 19),
#   ('jason', 19),
#   ('nathanias', 19),
#   ('remission', 19),
#   ('scandal', 19),
#   ('sem', 19),
#   ('sisara', 19),
#   ('supper', 19),
#   ('titus', 19),
#   ('amri', 18),
#   ('anathema', 18),
#   ('asor', 18),
#   ('bethsames', 18),
#   ('bushel', 18),
#   ('chusai', 18),
#   ('edict', 18),
#   ('immolate', 18),
#   ('ismael', 18),
#   ('joatham', 18),
#   ('nachor', 18),
#   ('ptolemais', 18),
#   ('susan', 18),
#   ('tharsis', 18),
#   ('timotheus', 18),
#   ('unction', 18),
#   ('achimelech', 17),
#   ('aminadab', 17),
#   ('ceila', 17),
#   ('elisama', 17),
#   ('ephesus', 17),
#   ('gibbet', 17),
#   ('henoch', 17),
#   ('jephte', 17),
#   ('labourer', 17),
#   ('menelaus', 17),
#   ('micha', 17),
#   ('michol', 17),
#   ('nathinites', 17),
#   ('pherezite', 17),
#   ('propitiatory', 17),
#   ('rabsaces', 17),
#   ('siba', 17),
#   ('thersa', 17),
#   ('achitob', 16),
#   ('asael', 16),
#   ('caesarea', 16),
#   ('capharnaum', 16),
#   ('fidelity', 16),
#   ('hananias', 16),
#   ('idithun', 16),
#   ('maasias', 16),
#   ('nabuzardan', 16),
#   ('noemi', 16),
#   ('ramatha', 16),
#   ('scandalized', 16),
#   ('abdenago', 15),
#   ('achimaas', 15),
#   ('achior', 15),
#   ('aggeus', 15),
#   ('ahias', 15),
#   ('alcimus', 15),
#   ('ascalon', 15),
#   ('baptist', 15),
#   ('cock', 15),
#   ('eliasib', 15),
#   ('jechonias', 15),
#   ('jephone', 15),
#   ('jerobaal', 15),
#   ('misach', 15),
#   ('palsy', 15),
#   ('siceleg', 15),
#   ('sidrach', 15),
#   ('amarias', 14),
#   ('bethsura', 14),
#   ('caree', 14),
#   ('cilicia', 14),
#   ('concupiscence', 14),
#   ('confidently', 14),
#   ('hesron', 14),
#   ('incredulous', 14),
#   ('josedec', 14),
#   ('lazarus', 14),
#   ('michas', 14),
#   ('miphiboseth', 14),
#   ('oza', 14),
#   ('oziel', 14),
#   ('remmon', 14),
#   ('salathiel', 14),
#   ('scandalize', 14),
#   ('sophonias', 14),
#   ('zara', 14),
#   ('abounded', 13),
#   ('apollonius', 13),
#   ('athalia', 13),
#   ('barac', 13),
#   ('countryman', 13),
#   ('festus', 13),
#   ('gazer', 13),
#   ('heliodorus', 13),
#   ('isboseth', 13),
#   ('jemini', 13),
#   ('pastor', 13),
#   ('principality', 13),
#   ('romelia', 13),
#   ('semeia', 13),
#   ('silas', 13),
#   ('soba', 13),
#   ('thinketh', 13),
#   ('abdias', 12),
#   ('abiu', 12),
#   ('alleluia', 12),
#   ('arphaxad', 12),
#   ('astaroth', 12),
#   ('berzellai', 12),
#   ('bethania', 12),
#   ('bethsabee', 12),
#   ('bethsan', 12),
#   ('bethulia', 12),
#   ('cedron', 12),
#   ('commend', 12),
#   ('eliacim', 12),
#   ('giezi', 12),
#   ('iscariot', 12),
#   ('magdalen', 12),
#   ('manue', 12),
#   ('moholi', 12),
#   ('moloch', 12),
#   ('pharan', 12),
#   ('sadducee', 12),
#   ('salmana', 12),
#   ('sicle', 12),
#   ('sobal', 12),
#   ('thare', 12),
#   ('thecua', 12),
#   ('thessalonian', 12),
#   ('thomas', 12),
#   ('zebedee', 12),
#   ('zechri', 12),
#   ('agrippa', 11),
#   ('aromatical', 11),
#   ('barachias', 11),
#   ('beelzebub', 11),
#   ('cadesbarne', 11),
#   ('caul', 11),
#   ('cenez', 11),
#   ('clemency', 11),
#   ('dabir', 11),
#   ('ephesian', 11),
#   ('furlong', 11),
#   ('gazara', 11),
#   ('gorgias', 11),
#   ('habacuc', 11),
#   ('joachin', 11),
#   ('machmas', 11),
#   ('mageddo', 11),
#   ('mambre', 11),
#   ('melcha', 11),
#   ('phacee', 11),
#   ('raphaim', 11),
#   ('rasin', 11),
#   ('resemblance', 11),
#   ('rohob', 11),
#   ('unspotted', 11),
#   ('zebee', 11),
#   ('abiron', 10),
#   ('accuser', 10),
#   ('achaia', 10),
#   ('addo', 10),
#   ('ammiud', 10),
#   ('apollo', 10),
#   ('baltassar', 10),
#   ('baptize', 10),
#   ('barabbas', 10),
#   ('carefulness', 10),
#   ('charmi', 10),
#   ('corruptible', 10),
#   ('cyrene', 10),
#   ('eliu', 10),
#   ('enkindled', 10),
#   ('ennom', 10),
#   ('ephrata', 10),
#   ('gabelus', 10),
#   ('galaadite', 10),
#   ('gerara', 10),
#   ('gessen', 10),
#   ('hethites', 10),
#   ('jahiel', 10),
#   ('melchias', 10),
#   ('melchisedech', 10),
#   ('ness', 10),
#   ('olivet', 10),
#   ('reprobate', 10),
#   ('samma', 10),
#   ('sanaballat', 10),
#   ('saraias', 10),
#   ('segor', 10),
#   ('sesac', 10),
#   ('susanna', 10),
#   ('teth', 10),
#   ('thabor', 10),
#   ('theman', 10),
#   ('thrashingfloor', 10),
#   ('zambri', 10),
#   ('aforesaid', 9),
#   ('bathuel', 9),
#   ('bethoron', 9),
#   ('bosor', 9),
#   ('bosra', 9),
#   ('caiphas', 9),
#   ('cedes', 9),
#   ('cornelius', 9),
#   ('cyprus', 9),
#   ('dren', 9),
#   ('effeminate', 9),
#   ('emmer', 9),
#   ('enrolled', 9),
#   ('ethai', 9),
#   ('felix', 9),
#   ('fornicator', 9),
#   ('gainsay', 9),
#   ('galatian', 9),
#   ('hanon', 9),
#   ('hemor', 9),
#   ('idumea', 9),
#   ('isaar', 9),
#   ('lebna', 9),
#   ('levitical', 9),
#   ('maasia', 9),
#   ('maceda', 9),
#   ('maresa', 9),
#   ('mathania', 9),
#   ('mello', 9),
#   ('mildness', 9),
#   ('misael', 9),
#   ('modin', 9),
#   ('nahasson', 9),
#   ('nazarite', 9),
#   ('nerias', 9),
#   ('ozi', 9),
#   ('proselyte', 9),
#   ('rabbath', 9),
#   ('raphael', 9),
#   ('reblatha', 9),
#   ('salphaad', 9),
#   ('sina', 9),
#   ('sobna', 9),
#   ('soccoth', 9),
#   ('spartan', 9),
#   ('stater', 9),
#   ('stout', 9),
#   ('vasthi', 9),
#   ('vested', 9),
#   ('zachary', 9),
#   ('zare', 9),
#   ('accub', 8),
#   ('ada', 8),
#   ('aphec', 8),
#   ('assur', 8),
#   ('barnfloor', 8),
#   ('bethsaida', 8),
#   ('bochri', 8),
#   ('bruchus', 8),
#   ('casleu', 8),
#   ('cedmihel', 8),
#   ('cephas', 8),
#   ('cerethi', 8),
#   ('chamos', 8),
#   ('chobar', 8),
#   ('chonenias', 8),
#   ('cinite', 8),
#   ('cockle', 8),
#   ('communicate', 8),
#   ('debbora', 8),
#   ('dison', 8),
#   ('enac', 8),
#   ('enacims', 8),
#   ('fried', 8),
#   ('galilean', 8),
#   ('gelboe', 8),
#   ('gessur', 8),
#   ('grate', 8),
#   ('incorruption', 8),
#   ('inebriated', 8),
#   ('jehus', 8),
#   ('jezrahelite', 8),
#   ('jude', 8),
#   ('lawyer', 8),
#   ('macedonian', 8),
#   ('malaleel', 8),
#   ('malediction', 8),
#   ('manahem', 8),
#   ('menstruous', 8),
#   ('nechao', 8),
#   ('nobe', 8),
#   ('oolibama', 8),
#   ('palestine', 8),
#   ('phadaia', 8),
#   ('phaleg', 8),
#   ('phanuel', 8),
#   ('phasga', 8),
#   ('phassur', 8),
#   ('ple', 8),
#   ('rahuel', 8),
#   ('rover', 8),
#   ('saphat', 8),
#   ('saraia', 8),
#   ('sebeon', 8),
#   ('sechenias', 8),
#   ('signified', 8),
#   ('socho', 8),
#   ('sunamitess', 8),
#   ('tempting', 8),
#   ('thamna', 8),
#   ('thau', 8),
#   ('vants', 8),
#   ('achinoam', 7),
#   ('admired', 7),
#   ('aialon', 7),
#   ('aod', 7),
#   ('asaia', 7),
#   ('barbarian', 7),
#   ('baria', 7),
#   ('beroth', 7),
#   ('beseleel', 7),
#   ('cainan', 7),
#   ('cariathaim', 7),
#   ('choir', 7),
#   ('crete', 7),
#   ('dalila', 7),
#   ('darksome', 7),
#   ('dissimulation', 7),
#   ('edrai', 7),
#   ('esron', 7),
#   ('fered', 7),
#   ('gabaonites', 7),
#   ('galatia', 7),
#   ('gessuri', 7),
#   ('gethite', 7),
#   ('gnashing', 7),
#   ('hevites', 7),
#   ('hopeth', 7),
#   ('ignorantly', 7),
#   ('jerameel', 7),
#   ('joathan', 7),
#   ('lobna', 7),
#   ('luza', 7),
#   ('lysimachus', 7),
#   ('lystra', 7),
#   ('madianites', 7),
#   ('mosoch', 7),
#   ('noised', 7),
#   ('odollam', 7),
#   ('phelethi', 7),
#   ('philippian', 7),
#   ('phogor', 7),
#   ('rael', 7),
#   ('revenger', 7),
#   ('rubenites', 7),
#   ('saluteth', 7),
#   ('seboim', 7),
#   ('sennaar', 7),
#   ('socoth', 7),
#   ('stephen', 7),
#   ('sue', 7),
#   ('taphnis', 7),
#   ('tetrarch', 7),
#   ('ther', 7),
#   ('zamri', 7),
#   ('abdemelech', 6),
#   ('achobor', 6),
#   ('adaia', 6),
#   ('aia', 6),
#   ('aleph', 6),
#   ('amalecites', 6),
#   ('andronicus', 6),
#   ('aquila', 6),
#   ('areuna', 6),
#   ('arphad', 6),
#   ('asel', 6),
#   ('asiongaber', 6),
#   ('baltasar', 6),
#   ('baptizing', 6),
#   ('barrenness', 6),
#   ('bates', 6),
#   ('believest', 6),
#   ('bendeth', 6),
#   ('blaspheming', 6),
#   ('bled', 6),
#   ('buckle', 6),
#   ('calumniate', 6),
#   ('caph', 6),
#   ('catcheth', 6),
#   ('chastising', 6),
#   ('chrysolite', 6),
#   ('chus', 6),
#   ('coloured', 6),
#   ('coph', 6),
#   ('corinth', 6),
#   ('cornet', 6),
#   ('dadan', 6),
#   ('daleth', 6),
#   ('elasa', 6),
#   ('engaddi', 6),
#   ('enos', 6),
#   ('ephra', 6),
#   ('esthaol', 6),
#   ('fiftyfour', 6),
#   ('fiftythree', 6),
#   ('foresaid', 6),
#   ('fryingpan', 6),
#   ('gabaath', 6),
#   ('gersom', 6),
#   ('ghimel', 6),
#   ('glorying', 6),
#   ('haber', 6),
#   ('hanania', 6),
#   ('hasabias', 6),
#   ('hebal', 6),
#   ('herodias', 6),
#   ('hevila', 6),
#   ('horma', 6),
#   ('hosa', 6),
#   ('hosanna', 6),
#   ('howled', 6),
#   ('iconium', 6),
#   ('idaia', 6),
#   ('immoveable', 6),
#   ('incorruptible', 6),
#   ('ivy', 6),
#   ('jahel', 6),
#   ('jamnia', 6),
#   ('jasa', 6),
#   ('jectan', 6),
#   ('jezonias', 6),
#   ('jezrael', 6),
#   ('joahe', 6),
#   ('lais', 6),
#   ('malachias', 6),
#   ('melchia', 6),
#   ('mem', 6),
#   ('ministration', 6),
#   ('mosa', 6),
#   ('najoth', 6),
#   ('neighbouring', 6),
#   ('nicanors', 6),
#   ('ooliba', 6),
#   ('othoniel', 6),
#   ('pamphylia', 6),
#   ('parlour', 6),
#   ('persecutest', 6),
#   ('phahath', 6),
#   ('pharos', 6),
#   ('phe', 6),
#   ('phenicia', 6),
#   ('pherezites', 6),
#   ('philippi', 6),
#   ('pillaged', 6),
#   ('preacheth', 6),
#   ('refreshment', 6),
#   ('resisteth', 6),
#   ('riotousness', 6),
#   ('sade', 6),
#   ('samech', 6),
#   ('saphatias', 6),
#   ('saron', 6),
#   ('selemias', 6),
#   ('sephor', 6),
#   ('sextary', 6),
#   ('shieldbearers', 6),
#   ('shorn', 6),
#   ('silonite', 6),
#   ('sixtysix', 6),
#   ('sobriety', 6),
#   ('tanis', 6),
#   ('tapestry', 6),
#   ('ter', 6),
#   ('thahath', 6),
#   ('thema', 6),
#   ('themanite', 6),
#   ('thesbite', 6),
#   ('thessalonica', 6),
#   ('thola', 6),
#   ('thubal', 6),
#   ('thyine', 6),
#   ('troas', 6),
#   ('turpentine', 6),
#   ('tyrians', 6),
#   ('unfruitful', 6),
#   ('vau', 6),
#   ('whale', 6),
#   ('zachur', 6),
#   ('zain', 6),
#   ('zeb', 6),
#   ('zelpha', 6),
#   ('abiam', 5),
#   ('abisag', 5),
#   ('abisue', 5),
#   ('aduram', 5),
#   ('alabaster', 5),
#   ('alpheus', 5),
#   ('amadathi', 5),
#   ('amalecite', 5),
#   ('ammisaddai', 5),
#   ('apostleship', 5),
#   ('aqueduct', 5),
#   ('arachite', 5),
#   ('aristarchus', 5),
#   ('asan', 5),
#   ('athens', 5),
#   ('athersatha', 5),
#   ('azeca', 5),
#   ('azmoth', 5),
#   ('beelphegor', 5),
#   ('bennui', 5),
#   ('bocci', 5),
#   ('bonni', 5),
#   ('brothel', 5),
#   ('cana', 5),
#   ('cappadocia', 5),
#   ('cariatharbe', 5),
#   ('cendebeus', 5),
#   ('cethim', 5),
#   ('chargeable', 5),
#   ('charmel', 5),
#   ('cheerfulness', 5),
#   ('chodorlahomor', 5),
#   ('cison', 5),
#   ('colossian', 5),
#   ('crew', 5),
#   ('deceitfulness', 5),
#   ('derstanding', 5),
#   ('detracted', 5),
#   ('diana', 5),
#   ('dina', 5),
#   ('duel', 5),
#   ('earlets', 5),
#   ('earnest', 5),
#   ('eleale', 5),
#   ('elisaphan', 5),
#   ('emulation', 5),
#   ('endeavoured', 5),
#   ('epha', 5),
#   ('eser', 5),
#   ('eupator', 5),
#   ('examination', 5),
#   ('extortioner', 5),
#   ('ezricam', 5),
#   ('fastening', 5),
#   ('gamarias', 5),
#   ('gebbethon', 5),
#   ('hanameel', 5),
#   ('haseroth', 5),
#   ('hattus', 5),
#   ('hus', 5),
#   ('invocated', 5),
#   ('ished', 5),
#   ('ismaelites', 5),
#   ('jemna', 5),
#   ('jesi', 5),
#   ('jesia', 5),
#   ('jezrahelitess', 5),
#   ('jupiter', 5),
#   ('laodicea', 5),
#   ('lightsome', 5),
#   ('lobni', 5),
#   ('macelloth', 5),
#   ('machati', 5),
#   ('manaim', 5),
#   ('manger', 5),
#   ('maraioth', 5),
#   ('mathanias', 5),
#   ('medaba', 5),
#   ('melchisua', 5),
#   ('melchom', 5),
#   ('miamin', 5),
#   ('molest', 5),
#   ('multi', 5),
#   ('nabo', 5),
#   ('namsi', 5),
#   ('nicodemus', 5),
#   ('ninetynine', 5),
#   ('noa', 5),
#   ('nourisheth', 5),
#   ('obols', 5),
#   ('oduia', 5),
#   ('oolla', 5),
#   ('overcometh', 5),
#   ('pap', 5),
#   ('parasceve', 5),
#   ('pestilent', 5),
#   ('phadassur', 5),
#   ('phallu', 5),
#   ('phegiel', 5),
#   ('phua', 5),
#   ('pined', 5),
#   ('pisseth', 5),
#   ('pontus', 5),
#   ('predestinated', 5),
#   ('prevaricator', 5),
#   ('proconsul', 5),
#   ('promiseth', 5),
#   ('rabba', 5),
#   ('railing', 5),
#   ('rainbow', 5),
#   ('raphaia', 5),
#   ('raphidim', 5),
#   ('recem', 5),
#   ('reprehend', 5),
#   ('rump', 5),
#   ('sabama', 5),
#   ('salamiel', 5),
#   ('salmanasar', 5),
#   ('sarug', 5),
#   ('sedeur', 5),
#   ('seleucus', 5),
#   ('senate', 5),
#   ('ser', 5),
#   ('seventyfour', 5),
#   ('siloe', 5),
#   ('sitten', 5),
#   ('sixtyfive', 5),
#   ('sojournment', 5),
#   ('surisaddai', 5),
#   ('sycamore', 5),
#   ('taphua', 5),
#   ('tarsus', 5),
#   ('telmon', 5),
#   ('tolerable', 5),
#   ('tude', 5),
#   ('unicorn', 5),
#   ('unspeakable', 5),
#   ('upbraided', 5),
#   ('upbraideth', 5),
#   ('vehemently', 5),
#   ('vocation', 5),
#   ('wain', 5),
#   ('wizard', 5),
#   ('abinoem', 4),
#   ('adjoining', 4),
#   ('adoreth', 4),
#   ('afflicteth', 4),
#   ('aginst', 4),
#   ('amalech', 4),
#   ('amiable', 4),
#   ('arapha', 4),
#   ('arimathea', 4),
#   ('asedoth', 4),
#   ('asir', 4),
#   ('awaking', 4),
#   ('axa', 4),
#   ('azotians', 4),
#   ('azuba', 4),
#   ('azymes', 4),
#   ('baala', 4),
#   ('baldad', 4),
#   ('bartholomew', 4),
#   ('bate', 4),
#   ('bechor', 4),
#   ('beelteem', 4),
#   ('berea', 4),
#   ('brake', 4),
#   ('bravest', 4),
#   ('brokest', 4),
#   ('burthen', 4),
#   ('caathites', 4),
#   ('cabin', 4),
#   ('cabseel', 4),
#   ('calvary', 4),
#   ('cariathsepher', 4),
#   ('carioth', 4),
#   ('celesyria', 4),
#   ('cenereth', 4),
#   ('cerning', 4),
#   ('cetura', 4),
#   ('chamaam', 4),
#   ('chanaana', 4),
#   ('chastiseth', 4),
#   ('chil', 4),
#   ('clearest', 4),
#   ('commiseration', 4),
#   ('commmitteth', 4),
#   ('condescend', 4),
#   ('consenting', 4),
#   ('contrariwise', 4),
#   ('convicted', 4),
#   ('copulation', 4),
#   ('cording', 4),
#   ('damnation', 4),
#   ('decease', 4),
#   ('defileth', 4),
#   ('der', 4),
#   ('derbe', 4),
#   ('detraction', 4),
#   ('detractor', 4),
#   ('didrachmas', 4),
#   ('discoursed', 4),
#   ('disorderly', 4),
#   ('dositheus', 4),
#   ('dothain', 4),
#   ('dred', 4),
#   ('ecbatana', 4),
#   ('edged', 4),
#   ('eliachim', 4),
#   ('elisur', 4),
#   ('emmaus', 4),
#   ('enlighteneth', 4),
#   ('ered', 4),
#   ('evangelist', 4),
#   ('farewell', 4),
#   ('fortification', 4),
#   ('freeman', 4),
#   ('frumenty', 4),
#   ('gaas', 4),
#   ('galaadites', 4),
#   ('garizim', 4),
#   ('gerasens', 4),
#   ('gergesite', 4),
#   ('gersonites', 4),
#   ('gethites', 4),
#   ('gethremmon', 4),
#   ('glutted', 4),
#   ('gomor', 4),
#   ('goodman', 4),
#   ('gossem', 4),
#   ('grafted', 4),
#   ('gratis', 4),
#   ('groaned', 4),
#   ('harmless', 4),
#   ('hasabia', 4),
#   ('hasebia', 4),
#   ('hasub', 4),
#   ('hegla', 4),
#   ('heliopolis', 4),
#   ('helles', 4),
#   ('hissed', 4),
#   ('impoverished', 4),
#   ('ings', 4),
#   ('jaboc', 4),
#   ('jadihel', 4),
#   ('jaser', 4),
#   ('jasub', 4),
#   ('jaziel', 4),
#   ('jemla', 4),
#   ('jesua', 4),
#   ('jethrite', 4),
#   ('joacim', 4),
#   ('jozabed', 4),
#   ('lately', 4),
#   ('lateward', 4),
#   ('lodgeth', 4),
#   ('lydda', 4),
#   ('lydia', 4),
#   ('masma', 4),
#   ('mathusala', 4),
#   ('melluch', 4),
#   ('ments', 4),
#   ('mild', 4),
#   ('molada', 4),
#   ('molested', 4),
#   ('naasson', 4),
#   ('nabajoth', 4),
#   ('nazarites', 4),
#   ('necoda', 4),
#   ('nemrod', 4),
#   ('ninetyfive', 4),
#   ('numenius', 4),
#   ('obdia', 4),
#   ('offerest', 4),
#   ('ooliab', 4),
#   ('oronaim', 4),
#   ('overreached', 4),
#   ('paraclete', 4),
#   ('pear', 4),
#   ('pentecost', 4),
#   ('pharathonite', 4),
#   ('phatures', 4),
#   ('phenice', 4),
#   ('pheshur', 4),
#   ('phihahiroth', 4),
#   ('philemon', 4),
#   ('pontius', 4),
#   ('priscilla', 4),
#   ('prostituted', 4),
#   ('quarrelled', 4),
#   ('quickeneth', 4),
#   ('readeth', 4),
#   ('regma', 4),
#   ('respha', 4),
#   ('reum', 4),
#   ('revellings', 4),
#   ('rogel', 4),
#   ('rohobia', 4),
#   ('sackbut', 4),
#   ('sacrilegious', 4),
#   ('salomith', 4),
#   ('samir', 4),
#   ('samsai', 4),
#   ('sanctifieth', 4),
#   ('sanir', 4),
#   ('saphatia', 4),
#   ('sardius', 4),
#   ('sassabasar', 4),
#   ('sciniphs', 4),
#   ('sechem', 4),
#   ('sella', 4),
#   ('semeron', 4),
#   ('semiramoth', 4),
#   ('sephora', 4),
#   ('serebia', 4),
#   ('seventyseven', 4),
#   ('shewest', 4),
#   ('slighted', 4),
#   ('slipt', 4),
#   ('slumbered', 4),
#   ('somer', 4),
#   ('sophar', 4),
#   ('spade', 4),
#   ('stew', 4),
#   ('stharbuzanai', 4),
#   ('striker', 4),
#   ...]}
